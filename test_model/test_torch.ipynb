# %%
! pip list

# %%
import torch
import torchvision

print(f"PyTorch version: {torch.__version__}")
print(f"torchvision version: {torchvision.__version__}")
print(f"Is CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
else:
    print("CUDA is not available.")

# %% [markdown]
# # 1. YOLO 객체 탐지 (미구현)

# %% [markdown]
# ### yolov5 저장소 클론 (혹은 pip install ultralytics 로 yolov5 / yolov8 사용 가능)
# git clone https://github.com/ultralytics/yolov5.git
# cd yolov5
# pip install -r requirements.txt

# %%
import torch
from PIL import Image
import cv2

# 1) YOLO 모델 불러오기 (yolov5s 등 가중치)
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# 2) 이미지 로드
img_path = 'test_image.jpg'
results = model(img_path, size=640)

# 3) 객체 중에서 'person' 혹은 'face' 클래스 필터링
#   -> yolov5s는 기본 COCO 클래스(80종) 중 'person'만 존재. 
#      'face'만 검출하려면 얼굴 전용 가중치나 custom model이 필요.
df = results.pandas().xyxy[0]  # detection 결과를 pandas로
for idx, row in df.iterrows():
    cls_name = row['name']   # 클래스 이름
    conf = row['confidence']
    if cls_name == 'person': 
        x1, y1, x2, y2 = int(row['xmin']), int(row['ymin']), int(row['xmax']), int(row['ymax'])
        # crop
        # ...

# 만약 얼굴만 검출하고 싶다면
# -> yolov5 face 전용 custom 모델 사용

# %%
import cv2
import torchvision.transforms as T

transform = T.Compose([
    T.Resize((224, 224)),      # 모델 입력 크기에 맞게
    T.ToTensor(),
    T.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])  # ImageNet 통계값
])

img_cv2 = cv2.imread(img_path)
crop_img = img_cv2[y1:y2, x1:x2, :]  # bounding box 영역 자르기
crop_img_rgb = cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB)

# PIL 객체로 변환 후 torch.Tensor로
crop_pil = Image.fromarray(crop_img_rgb)
input_tensor = transform(crop_pil)
input_tensor = input_tensor.unsqueeze(0)  # 배치 차원 추가 => shape (1, C, H, W)

# %% [markdown]
# # 2. 이진 분류 모델

# %% [markdown]
# ### 1-데이터셋 및 DataLoader 구성

# %%
import torch
import torchvision.models as models
import torch.nn as nn

# -------------------------------------
# 0) device 설정
# -------------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# -------------------------------------
# 1) 모델 선언 및 마지막 레이어 교체
# -------------------------------------
model = models.efficientnet_b0(pretrained=True)  # ImageNet 사전학습
num_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_features, 2)  # Fake vs Real (2클래스)

# -------------------------------------
# 2) 데이터 로더 설정
# -------------------------------------
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
import os

base_dir = os.getcwd()  # 현재 작업 디렉토리
train_dir = os.path.join(base_dir, 'Train')
val_dir   = os.path.join(base_dir, 'Validation')
test_dir  = os.path.join(base_dir, 'Test')

batch = 16
img_resized = (128, 128)

train_transform = transforms.Compose([
    transforms.Resize(img_resized),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],
                         [0.229,0.224,0.225])
])

test_transform = transforms.Compose([
    transforms.Resize(img_resized),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],
                         [0.229,0.224,0.225])
])

train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
val_dataset   = datasets.ImageFolder(root=val_dir, transform=test_transform)
test_dataset  = datasets.ImageFolder(root=test_dir, transform=test_transform)

train_loader  = DataLoader(train_dataset, batch_size=batch, shuffle=True,  num_workers=0)
val_loader    = DataLoader(val_dataset,   batch_size=batch, shuffle=False, num_workers=0)
test_loader   = DataLoader(test_dataset,  batch_size=batch, shuffle=False, num_workers=0)

# -------------------------------------
# 3) 학습 설정 (Loss, Optimizer 등)
# -------------------------------------
import torch.optim as optim

model = model.to(device)  # 여기서 device로 모델을 올림
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

num_epochs = 10
# Out:
# c:\Users\user\.conda\envs\torch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\user\.conda\envs\torch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ### 2-모델 훈련(파인튜닝) 및 검증

# %%
# -------------------------------------
# 4) Training Loop
# -------------------------------------
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        _, preds = torch.max(outputs, 1)
        correct += torch.sum(preds == labels).item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc  = correct / total

    # validation
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for val_images, val_labels in val_loader:
            val_images, val_labels = val_images.to(device), val_labels.to(device)
            val_outputs = model(val_images)
            v_loss = criterion(val_outputs, val_labels)
            val_loss += v_loss.item() * val_images.size(0)
            _, v_preds = torch.max(val_outputs, 1)
            val_correct += torch.sum(v_preds == val_labels).item()
            val_total += val_labels.size(0)

    val_epoch_loss = val_loss / val_total
    val_epoch_acc  = val_correct / val_total

    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"Train Loss: {epoch_loss:.4f} Train Acc: {epoch_acc:.4f} | "
          f"Val Loss: {val_epoch_loss:.4f} Val Acc: {val_epoch_acc:.4f}")

# -------------------------------------
# 5) Model Save
# -------------------------------------
pth_name = "binary_test_244.pth"
torch.save(model.state_dict(), pth_name)
# Out:
# Epoch [1/10] Train Loss: 0.1916 Train Acc: 0.9274 | Val Loss: 0.0893 Val Acc: 0.9683
# Epoch [2/10] Train Loss: 0.0702 Train Acc: 0.9760 | Val Loss: 0.0935 Val Acc: 0.9657
# Epoch [3/10] Train Loss: 0.0372 Train Acc: 0.9873 | Val Loss: 0.1516 Val Acc: 0.9532
# Epoch [4/10] Train Loss: 0.0274 Train Acc: 0.9912 | Val Loss: 0.0958 Val Acc: 0.9706
# Epoch [5/10] Train Loss: 0.0221 Train Acc: 0.9933 | Val Loss: 0.1597 Val Acc: 0.9600
# Epoch [6/10] Train Loss: 0.0274 Train Acc: 0.9900 | Val Loss: 0.0730 Val Acc: 0.9742
# Epoch [7/10] Train Loss: 0.0145 Train Acc: 0.9952 | Val Loss: 0.0635 Val Acc: 0.9801
# Epoch [8/10] Train Loss: 0.0159 Train Acc: 0.9943 | Val Loss: 0.1042 Val Acc: 0.9689
# Epoch [9/10] Train Loss: 0.0236 Train Acc: 0.9922 | Val Loss: 0.0587 Val Acc: 0.9833
# Epoch [10/10] Train Loss: 0.0120 Train Acc: 0.9957 | Val Loss: 0.0546 Val Acc: 0.9840

# %% [markdown]
# ### 3-테스트(추가 평가)

# %%
# -------------------------------------
# 6) Test
# -------------------------------------
model.eval()

test_loss = 0.0
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)
        test_loss += loss.item() * images.size(0)

        _, preds = torch.max(outputs, 1)
        correct += torch.sum(preds == labels).item()
        total += labels.size(0)

avg_loss = test_loss / total
accuracy = correct / total

print(f"[Test] Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
# Out:
# [Test] Loss: 0.6456, Accuracy: 0.8414

# %% [markdown]
# ### 99-TorchScript(.pt) 병합 (모델 구조 + 가중치.pth)

# %%
import torch
import torchvision.models as models
import torch.nn as nn

# 1) 모델 정의 (학습 때와 동일 구조)
model = models.efficientnet_b0(pretrained=False)
num_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_features, 2)
model.load_state_dict(torch.load(pth_name, map_location="cpu"))
model.eval()

# 2) TorchScript 변환
model_name = "efficientnet_b0_deepfake_128.pt"
scripted_model = torch.jit.script(model)  # 또는 torch.jit.trace(model, example_input)
scripted_model.save(model_name)
# Out:
# c:\Users\user\.conda\envs\torch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# C:\Users\user\AppData\Local\Temp\ipykernel_19660\240586017.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pth_name, map_location="cpu"))

# %% [markdown]
# ## 외부 이미지 테스트

# %%
import os
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image

# 1) device 설정 (GPU 사용 가능 시 GPU 할당)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 2) 모델 구조 정의 (학습 때와 동일하게)
model = torch.jit.load("efficientnet_b0_deepfake_128.pt", map_location=device)
model.eval()

# 4) 이미지 전처리 transform (학습 때와 동일하게)
img_resized = (128, 128)

transform = transforms.Compose([
    transforms.Resize(img_resized),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# 5) 예측할 이미지 폴더 경로
base_dir = os.getcwd()  # 현재 작업 디렉토리
image_folder = os.path.join(base_dir, 'sample')

# 6) 폴더 내 이미지들에 대해 일괄 추론
with torch.no_grad():
    for filename in os.listdir(image_folder):
        # 파일 확장자 확인 (jpg, png 등)
        if filename.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
            img_path = os.path.join(image_folder, filename)

            # 이미지 열기
            img = Image.open(img_path).convert('RGB')
            # 전처리
            img_tensor = transform(img).unsqueeze(0).to(device)  # shape: (1, C, H, W)

            # 모델 추론
            outputs = model(img_tensor)
            # 예: CrossEntropyLoss 기준 => argmax
            _, pred = torch.max(outputs, 1)

            # 0 -> Fake, 1 -> Real (ImageFolder 학습 기준)
            label_idx = pred.item()
            label_str = "Fake" if label_idx == 0 else "Real"

            print(f"[{filename}] => {label_str}")
# Out:
# [0000.png] => Fake
# [0150.png] => Real
# [0275.png] => Fake
# [10_20241130135752_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg] => Fake
# [14_20241130135832_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg] => Fake
# [god01.jpg] => Real
# [god02.jpg] => Real
# [god03.jpg] => Real

# %% [markdown]
# # 3. 다중 분류 모델

# %% [markdown]
# ### 1-데이터셋 및 DataLoader 구성

# %%
import torch
import torchvision.models as models
import torch.nn as nn
import time

# -------------------------------------
# 0) device 설정
# -------------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# -------------------------------------
# 1) 모델 선언 및 마지막 레이어 교체
# -------------------------------------
model = models.efficientnet_b0(pretrained=True)  # ImageNet 사전학습
num_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_features, 3)  # 3-class (AIGenerated, Fake, Real)

# -------------------------------------
# 2) 데이터 로더 설정
# -------------------------------------
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
import os

base_dir = os.getcwd()  # 현재 작업 디렉토리
train_dir = os.path.join(base_dir, 'Train')
val_dir   = os.path.join(base_dir, 'Validation')
test_dir  = os.path.join(base_dir, 'Test')

batch = 16
img_resized = (128, 128)

train_transform = transforms.Compose([
    transforms.Resize(img_resized),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],
                         [0.229,0.224,0.225])
])

test_transform = transforms.Compose([
    transforms.Resize(img_resized),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],
                         [0.229,0.224,0.225])
])

train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
val_dataset   = datasets.ImageFolder(root=val_dir, transform=test_transform)
test_dataset  = datasets.ImageFolder(root=test_dir, transform=test_transform)

train_loader  = DataLoader(train_dataset, batch_size=batch, shuffle=True,  num_workers=0, pin_memory=True)
val_loader    = DataLoader(val_dataset,   batch_size=batch, shuffle=False, num_workers=0, pin_memory=True)
test_loader   = DataLoader(test_dataset,  batch_size=batch, shuffle=False, num_workers=0, pin_memory=True)

# 클래스 인덱스 확인
print("Train Dataset class to index mapping:")
print(train_dataset.class_to_idx)


# -------------------------------------
# 3) 학습 설정 (Loss, Optimizer 등)
# -------------------------------------
import torch.optim as optim

model = model.to(device)  # 여기서 device로 모델을 올림
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

num_epochs = 10
# Out:
# c:\Users\user\.conda\envs\torch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\user\.conda\envs\torch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Train Dataset class to index mapping:
# {'AIGenerated': 0, 'Fake': 1, 'Real': 2}

# %% [markdown]
# ### 2-모델 훈련(파인튜닝) 및 검증

# %%
from tqdm import tqdm

# -------------------------------------
# 4) Training Loop
# -------------------------------------
total_start_time = time.time()

for epoch in range(num_epochs):
    start_time = time.time()  # 에포크 시작 시간 기록
    
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} - Training"):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        _, preds = torch.max(outputs, 1)
        correct += torch.sum(preds == labels).item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc  = correct / total

    # validation
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for val_images, val_labels in val_loader:
            val_images, val_labels = val_images.to(device), val_labels.to(device)
            val_outputs = model(val_images)
            v_loss = criterion(val_outputs, val_labels)
            val_loss += v_loss.item() * val_images.size(0)
            _, v_preds = torch.max(val_outputs, 1)
            val_correct += torch.sum(v_preds == val_labels).item()
            val_total += val_labels.size(0)

    val_epoch_loss = val_loss / val_total
    val_epoch_acc  = val_correct / val_total
    
    end_time = time.time()  # 에포크 종료 시간 기록
    epoch_duration = end_time - start_time  # 에포크 소요 시간 계산

    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"Train Loss: {epoch_loss:.4f} Train Acc: {epoch_acc:.4f} | "
          f"Val Loss: {val_epoch_loss:.4f} Val Acc: {val_epoch_acc:.4f} | "
          f"Time: {epoch_duration:.2f} sec")

total_end_time = time.time()
total_duration = total_end_time - total_start_time
print(f"Total Training Time: {total_duration/60:.2f} minutes")

# -------------------------------------
# 5) Model Save
# -------------------------------------
pth_name = "binary_test_3class_128.pth"
torch.save(model.state_dict(), pth_name)
# Out:
# Epoch 1/10 - Training: 100%|██████████| 551/551 [01:12<00:00,  7.56it/s]
# Epoch [1/10] Train Loss: 0.2722 Train Acc: 0.9033 | Val Loss: 0.1306 Val Acc: 0.9569 | Time: 97.84 sec
# Epoch 2/10 - Training: 100%|██████████| 551/551 [00:40<00:00, 13.58it/s]
# Epoch [2/10] Train Loss: 0.0966 Train Acc: 0.9651 | Val Loss: 0.1105 Val Acc: 0.9592 | Time: 58.42 sec
# Epoch 3/10 - Training: 100%|██████████| 551/551 [00:40<00:00, 13.61it/s]
# Epoch [3/10] Train Loss: 0.0567 Train Acc: 0.9817 | Val Loss: 0.0864 Val Acc: 0.9684 | Time: 58.30 sec
# Epoch 4/10 - Training: 100%|██████████| 551/551 [00:40<00:00, 13.58it/s]
# Epoch [4/10] Train Loss: 0.0334 Train Acc: 0.9890 | Val Loss: 0.1164 Val Acc: 0.9611 | Time: 58.40 sec
# Epoch 5/10 - Training: 100%|██████████| 551/551 [00:40<00:00, 13.70it/s]
# Epoch [5/10] Train Loss: 0.0344 Train Acc: 0.9878 | Val Loss: 0.1015 Val Acc: 0.9630 | Time: 58.23 sec
# Epoch 6/10 - Training: 100%|██████████| 551/551 [00:41<00:00, 13.29it/s]
# Epoch [6/10] Train Loss: 0.0230 Train Acc: 0.9926 | Val Loss: 0.1398 Val Acc: 0.9508 | Time: 59.66 sec
# Epoch 7/10 - Training: 100%|██████████| 551/551 [00:40<00:00, 13.48it/s]
# Epoch [7/10] Train Loss: 0.0176 Train Acc: 0.9951 | Val Loss: 0.1632 Val Acc: 0.9495 | Time: 58.84 sec
# Epoch 8/10 - Training: 100%|██████████| 551/551 [00:40<00:00, 13.45it/s]
# Epoch [8/10] Train Loss: 0.0220 Train Acc: 0.9931 | Val Loss: 0.1009 Val Acc: 0.9649 | Time: 58.78 sec
# Epoch 9/10 - Training: 100%|██████████| 551/551 [00:41<00:00, 13.27it/s]
# Epoch [9/10] Train Loss: 0.0136 Train Acc: 0.9958 | Val Loss: 0.1031 Val Acc: 0.9681 | Time: 59.57 sec
# Epoch 10/10 - Training: 100%|██████████| 551/551 [00:40<00:00, 13.55it/s]
# Epoch [10/10] Train Loss: 0.0126 Train Acc: 0.9957 | Val Loss: 0.0932 Val Acc: 0.9706 | Time: 58.40 sec
# Total Training Time: 10.44 minutes

# %% [markdown]
# ### 3-테스트(추가 평가)

# %%
# -------------------------------------
# 6) Test
# -------------------------------------
model.eval()

test_loss = 0.0
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)
        test_loss += loss.item() * images.size(0)

        _, preds = torch.max(outputs, 1)
        correct += torch.sum(preds == labels).item()
        total += labels.size(0)

avg_loss = test_loss / total
accuracy = correct / total

print(f"[Test] Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
# Out:
# [Test] Loss: 0.5539, Accuracy: 0.8655

# %% [markdown]
# ### 99-TorchScript(.ptl) 병합 (모델 구조 + 가중치.pth)

# %% [markdown]
# #### ai binary classification

# %%
import torch
import torchvision.models as models
import torch.nn as nn
from torch.utils.mobile_optimizer import optimize_for_mobile

# 모델 로드 및 TorchScript 변환
model = models.efficientnet_b0(pretrained=False)
num_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_features, 2)

model.load_state_dict(torch.load("ai_gen_b128_e10.pth", map_location="cpu"))
model.eval()

# 1) 스크립팅
scripted_model = torch.jit.script(model)

# 2) 모바일 최적화
optimized_model = optimize_for_mobile(scripted_model)

# 3) Lite Interpreter용으로 저장
optimized_model._save_for_lite_interpreter("efficientnet_b0_ai_gen.ptl")
# Out:
# c:\Users\user\.conda\envs\torch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\user\.conda\envs\torch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# C:\Users\user\AppData\Local\Temp\ipykernel_20412\3526195180.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("ai_gen_b128_e10.pth", map_location="cpu"))

# %%
import torch
import torchvision.models as models
import torch.nn as nn
from torch.utils.mobile_optimizer import optimize_for_mobile

# 1) 모델 정의 (학습 때와 동일 구조)
model = models.efficientnet_b0(pretrained=False)
num_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_features, 3)
model.load_state_dict(torch.load(pth_name, map_location="cpu"))
model.eval()

# 2) TorchScript 변환
model_name = "efficientnet_b0_3class_128.pt"
scripted_model = torch.jit.script(model)  # 또는 torch.jit.trace(model, example_input)
scripted_model.save(model_name)

# 모델 로드 및 TorchScript 변환
model = models.efficientnet_b0(pretrained=False)
num_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_features, 3)

model.load_state_dict(torch.load("face_3class_s128_e10.pth", map_location="cpu"))
model.eval()

# 1) 스크립팅
scripted_model = torch.jit.script(model)

# 2) 모바일 최적화
optimized_model = optimize_for_mobile(scripted_model)

# 3) Lite Interpreter용으로 저장
optimized_model._save_for_lite_interpreter("efficientnet_b0_deepfake_s128.ptl")
# Out:
# c:\Users\user\.conda\envs\torch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\user\.conda\envs\torch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# C:\Users\user\AppData\Local\Temp\ipykernel_21112\3887797595.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("face_3class_s128_e10.pth", map_location="cpu"))

# %% [markdown]
# ## 외부 이미지 테스트

# %%
import os
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image

# 1) device 설정 (GPU 사용 가능 시 GPU 할당)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 2) 모델 구조 정의 (학습 때와 동일하게)
model = torch.jit.load("efficientnet_b0_3class_128.pt", map_location=device)
model.eval()

# 4) 이미지 전처리 transform (학습 때와 동일하게)
img_resized = (128, 128)

transform = transforms.Compose([
    transforms.Resize(img_resized),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# 5) 예측할 이미지 폴더 경로
base_dir = os.getcwd()  # 현재 작업 디렉토리
image_folder = os.path.join(base_dir, 'sample')

# 6) 폴더 내 이미지들에 대해 일괄 추론
with torch.no_grad():
    for filename in os.listdir(image_folder):
        # 파일 확장자 확인 (jpg, png 등)
        if filename.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
            img_path = os.path.join(image_folder, filename)

            # 이미지 열기
            img = Image.open(img_path).convert('RGB')
            # 전처리
            img_tensor = transform(img).unsqueeze(0).to(device)  # shape: (1, C, H, W)

            # 모델 추론
            outputs = model(img_tensor)
            # 예: CrossEntropyLoss 기준 => argmax
            _, pred = torch.max(outputs, 1)

            # 0 -> Fake, 1 -> Real (ImageFolder 학습 기준)
            label_idx = pred.item()
            label_str = "AIGenerated" if label_idx == 0 else ("Fake" if label_idx == 1 else "Real")

            print(f"[{filename}] => {label_str}")
# Out:
# [64c47081-446f-4ff7-b811-3bb55cabcb35.jpg] => Fake
# [god01.jpg] => Real
# [god02.jpg] => Real
# [pexels-photo-2379005.jpeg] => Real

# %% [markdown]
# # 3. 통합 (yolo + detection) (미구현)

# %%
import torch
import cv2
from PIL import Image
import torchvision.transforms as T

# 1) YOLO 로드
face_detector = torch.hub.load('ultralytics/yolov5', 'custom', 'path/to/yolov5_face.pt')  
# 혹은 yolov5s, yolov8 등

# 2) 딥페이크 분류 모델 로드
model = models.efficientnet_b0()
# 분류기 교체
model.classifier[1] = nn.Linear(model.classifier[1].in_features, 2)
model.load_state_dict(torch.load('deepfake_classifier.pth'))
model.eval().cuda()  # GPU 사용

transform = T.Compose([
    T.Resize((224,224)),
    T.ToTensor(),
    T.Normalize([0.485,0.456,0.406], [0.229,0.224,0.225])
])

def detect_and_classify(img_path):
    # 1) 얼굴 검출
    results = face_detector(img_path, size=640)
    df = results.pandas().xyxy[0]

    img_cv2 = cv2.imread(img_path)
    h, w, _ = img_cv2.shape

    for idx, row in df.iterrows():
        x1, y1, x2, y2 = int(row['xmin']), int(row['ymin']), int(row['xmax']), int(row['ymax'])
        cls_conf = row['confidence']

        # 2) 얼굴 영역 crop
        crop_img = img_cv2[y1:y2, x1:x2, :]
        crop_img_rgb = cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB)
        pil_img = Image.fromarray(crop_img_rgb)
        
        input_tensor = transform(pil_img).unsqueeze(0).cuda()

        # 3) 딥페이크 분류
        with torch.no_grad():
            outputs = model(input_tensor)
            probs = torch.softmax(outputs, dim=1)  # CrossEntropyLoss 기반
            # probs[0,0] = fake 확률, probs[0,1] = real 확률 (ImageFolder 순서에 따라 다름)
            # 만약 fake 폴더가 index=0, real 폴더가 index=1이라면 아래와 같이
            fake_prob = probs[0,0].item()
            real_prob = probs[0,1].item()

        print(f"Face @({x1}, {y1}, {x2}, {y2}) => Fake: {fake_prob:.3f}, Real: {real_prob:.3f}")

# 테스트
detect_and_classify('test.jpg')

# %%
import os
import shutil

# 원본 경로와 복사할 경로 지정
source_root = r"C:\Users\user\Desktop\cropped_images"
destination_root = r"C:\Users\user\Desktop\selected_images"

# 대상 경로가 없으면 생성
os.makedirs(destination_root, exist_ok=True)

# 이미지 순차 이름 설정
counter = 1

# 각 폴더 내부 이미지를 5개씩 복사
for folder_name in os.listdir(source_root):
    folder_path = os.path.join(source_root, folder_name)

    # 폴더인지 확인
    if os.path.isdir(folder_path):
        images = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
        
        # 5개만 선택하여 복사
        for i, image in enumerate(images[-4:-1]):
            source_image_path = os.path.join(folder_path, image)

            # 순차 이름 생성
            destination_image_name = f"crop_{counter:04d}{os.path.splitext(image)[1]}"
            destination_image_path = os.path.join(destination_root, destination_image_name)

            # 복사 수행
            shutil.copy2(source_image_path, destination_image_path)

            print(f"{source_image_path} -> {destination_image_path}")

            # 카운터 증가
            counter += 1

print("이미지 복사가 완료되었습니다.")
# Out:
# C:\Users\user\Desktop\cropped_images\000_003\0300.png -> C:\Users\user\Desktop\selected_images\crop_0001.png
# C:\Users\user\Desktop\cropped_images\000_003\0325.png -> C:\Users\user\Desktop\selected_images\crop_0002.png
# C:\Users\user\Desktop\cropped_images\000_003\0350.png -> C:\Users\user\Desktop\selected_images\crop_0003.png
# C:\Users\user\Desktop\cropped_images\001_870\0375.png -> C:\Users\user\Desktop\selected_images\crop_0004.png
# C:\Users\user\Desktop\cropped_images\001_870\0400.png -> C:\Users\user\Desktop\selected_images\crop_0005.png
# C:\Users\user\Desktop\cropped_images\001_870\0425.png -> C:\Users\user\Desktop\selected_images\crop_0006.png
# C:\Users\user\Desktop\cropped_images\002_006\0600.png -> C:\Users\user\Desktop\selected_images\crop_0007.png
# C:\Users\user\Desktop\cropped_images\002_006\0625.png -> C:\Users\user\Desktop\selected_images\crop_0008.png
# C:\Users\user\Desktop\cropped_images\002_006\0650.png -> C:\Users\user\Desktop\selected_images\crop_0009.png
# C:\Users\user\Desktop\cropped_images\003_000\0225.png -> C:\Users\user\Desktop\selected_images\crop_0010.png
# C:\Users\user\Desktop\cropped_images\003_000\0250.png -> C:\Users\user\Desktop\selected_images\crop_0011.png
# C:\Users\user\Desktop\cropped_images\003_000\0275.png -> C:\Users\user\Desktop\selected_images\crop_0012.png
# C:\Users\user\Desktop\cropped_images\004_982\0225.png -> C:\Users\user\Desktop\selected_images\crop_0013.png
# C:\Users\user\Desktop\cropped_images\004_982\0250.png -> C:\Users\user\Desktop\selected_images\crop_0014.png
# C:\Users\user\Desktop\cropped_images\004_982\0275.png -> C:\Users\user\Desktop\selected_images\crop_0015.png
# C:\Users\user\Desktop\cropped_images\005_010\0300.png -> C:\Users\user\Desktop\selected_images\crop_0016.png
# C:\Users\user\Desktop\cropped_images\005_010\0325.png -> C:\Users\user\Desktop\selected_images\crop_0017.png
# C:\Users\user\Desktop\cropped_images\005_010\0350.png -> C:\Users\user\Desktop\selected_images\crop_0018.png
# C:\Users\user\Desktop\cropped_images\006_002\0225.png -> C:\Users\user\Desktop\selected_images\crop_0019.png
# C:\Users\user\Desktop\cropped_images\006_002\0250.png -> C:\Users\user\Desktop\selected_images\crop_0020.png
# C:\Users\user\Desktop\cropped_images\006_002\0275.png -> C:\Users\user\Desktop\selected_images\crop_0021.png
# C:\Users\user\Desktop\cropped_images\007_132\0425.png -> C:\Users\user\Desktop\selected_images\crop_0022.png
# C:\Users\user\Desktop\cropped_images\007_132\0450.png -> C:\Users\user\Desktop\selected_images\crop_0023.png
# C:\Users\user\Desktop\cropped_images\007_132\0475.png -> C:\Users\user\Desktop\selected_images\crop_0024.png
# C:\Users\user\Desktop\cropped_images\008_990\0550.png -> C:\Users\user\Desktop\selected_images\crop_0025.png
# C:\Users\user\Desktop\cropped_images\008_990\0575.png -> C:\Users\user\Desktop\selected_images\crop_0026.png
# C:\Users\user\Desktop\cropped_images\008_990\0600.png -> C:\Users\user\Desktop\selected_images\crop_0027.png
# C:\Users\user\Desktop\cropped_images\009_027\0500.png -> C:\Users\user\Desktop\selected_images\crop_0028.png
# C:\Users\user\Desktop\cropped_images\009_027\0525.png -> C:\Users\user\Desktop\selected_images\crop_0029.png
# C:\Users\user\Desktop\cropped_images\009_027\0550.png -> C:\Users\user\Desktop\selected_images\crop_0030.png
# C:\Users\user\Desktop\cropped_images\010_005\0375.png -> C:\Users\user\Desktop\selected_images\crop_0031.png
# C:\Users\user\Desktop\cropped_images\010_005\0400.png -> C:\Users\user\Desktop\selected_images\crop_0032.png
# C:\Users\user\Desktop\cropped_images\010_005\0425.png -> C:\Users\user\Desktop\selected_images\crop_0033.png
# C:\Users\user\Desktop\cropped_images\011_805\0550.png -> C:\Users\user\Desktop\selected_images\crop_0034.png
# C:\Users\user\Desktop\cropped_images\011_805\0575.png -> C:\Users\user\Desktop\selected_images\crop_0035.png
# C:\Users\user\Desktop\cropped_images\011_805\0600.png -> C:\Users\user\Desktop\selected_images\crop_0036.png
# C:\Users\user\Desktop\cropped_images\012_026\0275.png -> C:\Users\user\Desktop\selected_images\crop_0037.png
# C:\Users\user\Desktop\cropped_images\012_026\0300.png -> C:\Users\user\Desktop\selected_images\crop_0038.png
# C:\Users\user\Desktop\cropped_images\012_026\0325.png -> C:\Users\user\Desktop\selected_images\crop_0039.png
# C:\Users\user\Desktop\cropped_images\013_883\0250.png -> C:\Users\user\Desktop\selected_images\crop_0040.png
# C:\Users\user\Desktop\cropped_images\013_883\0275.png -> C:\Users\user\Desktop\selected_images\crop_0041.png
# C:\Users\user\Desktop\cropped_images\013_883\0300.png -> C:\Users\user\Desktop\selected_images\crop_0042.png
# C:\Users\user\Desktop\cropped_images\014_790\0600.png -> C:\Users\user\Desktop\selected_images\crop_0043.png
# C:\Users\user\Desktop\cropped_images\014_790\0625.png -> C:\Users\user\Desktop\selected_images\crop_0044.png
# C:\Users\user\Desktop\cropped_images\014_790\0650.png -> C:\Users\user\Desktop\selected_images\crop_0045.png
# C:\Users\user\Desktop\cropped_images\015_919\0350.png -> C:\Users\user\Desktop\selected_images\crop_0046.png
# C:\Users\user\Desktop\cropped_images\015_919\0375.png -> C:\Users\user\Desktop\selected_images\crop_0047.png
# C:\Users\user\Desktop\cropped_images\015_919\0400.png -> C:\Users\user\Desktop\selected_images\crop_0048.png
# C:\Users\user\Desktop\cropped_images\016_209\0600.png -> C:\Users\user\Desktop\selected_images\crop_0049.png
# C:\Users\user\Desktop\cropped_images\016_209\0625.png -> C:\Users\user\Desktop\selected_images\crop_0050.png
# C:\Users\user\Desktop\cropped_images\016_209\0650.png -> C:\Users\user\Desktop\selected_images\crop_0051.png
# C:\Users\user\Desktop\cropped_images\017_803\0300.png -> C:\Users\user\Desktop\selected_images\crop_0052.png
# C:\Users\user\Desktop\cropped_images\017_803\0325.png -> C:\Users\user\Desktop\selected_images\crop_0053.png
# C:\Users\user\Desktop\cropped_images\017_803\0350.png -> C:\Users\user\Desktop\selected_images\crop_0054.png
# C:\Users\user\Desktop\cropped_images\018_019\0350.png -> C:\Users\user\Desktop\selected_images\crop_0055.png
# C:\Users\user\Desktop\cropped_images\018_019\0375.png -> C:\Users\user\Desktop\selected_images\crop_0056.png
# C:\Users\user\Desktop\cropped_images\018_019\0400.png -> C:\Users\user\Desktop\selected_images\crop_0057.png
# C:\Users\user\Desktop\cropped_images\019_018\1300.png -> C:\Users\user\Desktop\selected_images\crop_0058.png
# C:\Users\user\Desktop\cropped_images\019_018\1325.png -> C:\Users\user\Desktop\selected_images\crop_0059.png
# C:\Users\user\Desktop\cropped_images\019_018\1350.png -> C:\Users\user\Desktop\selected_images\crop_0060.png
# C:\Users\user\Desktop\cropped_images\020_344\0300.png -> C:\Users\user\Desktop\selected_images\crop_0061.png
# C:\Users\user\Desktop\cropped_images\020_344\0325.png -> C:\Users\user\Desktop\selected_images\crop_0062.png
# C:\Users\user\Desktop\cropped_images\020_344\0350.png -> C:\Users\user\Desktop\selected_images\crop_0063.png
# C:\Users\user\Desktop\cropped_images\021_312\0350.png -> C:\Users\user\Desktop\selected_images\crop_0064.png
# C:\Users\user\Desktop\cropped_images\021_312\0375.png -> C:\Users\user\Desktop\selected_images\crop_0065.png
# C:\Users\user\Desktop\cropped_images\021_312\0400.png -> C:\Users\user\Desktop\selected_images\crop_0066.png
# C:\Users\user\Desktop\cropped_images\022_489\0225.png -> C:\Users\user\Desktop\selected_images\crop_0067.png
# C:\Users\user\Desktop\cropped_images\022_489\0250.png -> C:\Users\user\Desktop\selected_images\crop_0068.png
# C:\Users\user\Desktop\cropped_images\022_489\0275.png -> C:\Users\user\Desktop\selected_images\crop_0069.png
# C:\Users\user\Desktop\cropped_images\023_923\0475.png -> C:\Users\user\Desktop\selected_images\crop_0070.png
# C:\Users\user\Desktop\cropped_images\023_923\0500.png -> C:\Users\user\Desktop\selected_images\crop_0071.png
# C:\Users\user\Desktop\cropped_images\023_923\0525.png -> C:\Users\user\Desktop\selected_images\crop_0072.png
# C:\Users\user\Desktop\cropped_images\024_073\0200.png -> C:\Users\user\Desktop\selected_images\crop_0073.png
# C:\Users\user\Desktop\cropped_images\024_073\0250.png -> C:\Users\user\Desktop\selected_images\crop_0074.png
# C:\Users\user\Desktop\cropped_images\024_073\0275.png -> C:\Users\user\Desktop\selected_images\crop_0075.png
# C:\Users\user\Desktop\cropped_images\025_067\0650.png -> C:\Users\user\Desktop\selected_images\crop_0076.png
# C:\Users\user\Desktop\cropped_images\025_067\0675.png -> C:\Users\user\Desktop\selected_images\crop_0077.png
# C:\Users\user\Desktop\cropped_images\025_067\0700.png -> C:\Users\user\Desktop\selected_images\crop_0078.png
# C:\Users\user\Desktop\cropped_images\026_012\0225.png -> C:\Users\user\Desktop\selected_images\crop_0079.png
# C:\Users\user\Desktop\cropped_images\026_012\0250.png -> C:\Users\user\Desktop\selected_images\crop_0080.png
# C:\Users\user\Desktop\cropped_images\026_012\0275.png -> C:\Users\user\Desktop\selected_images\crop_0081.png
# C:\Users\user\Desktop\cropped_images\027_009\0150.png -> C:\Users\user\Desktop\selected_images\crop_0082.png
# C:\Users\user\Desktop\cropped_images\027_009\0225.png -> C:\Users\user\Desktop\selected_images\crop_0083.png
# C:\Users\user\Desktop\cropped_images\027_009\0250.png -> C:\Users\user\Desktop\selected_images\crop_0084.png
# C:\Users\user\Desktop\cropped_images\028_068\0350.png -> C:\Users\user\Desktop\selected_images\crop_0085.png
# C:\Users\user\Desktop\cropped_images\028_068\0375.png -> C:\Users\user\Desktop\selected_images\crop_0086.png
# C:\Users\user\Desktop\cropped_images\028_068\0400.png -> C:\Users\user\Desktop\selected_images\crop_0087.png
# C:\Users\user\Desktop\cropped_images\029_048\0325.png -> C:\Users\user\Desktop\selected_images\crop_0088.png
# C:\Users\user\Desktop\cropped_images\029_048\0350.png -> C:\Users\user\Desktop\selected_images\crop_0089.png
# C:\Users\user\Desktop\cropped_images\029_048\0375.png -> C:\Users\user\Desktop\selected_images\crop_0090.png
# C:\Users\user\Desktop\cropped_images\030_193\0200.png -> C:\Users\user\Desktop\selected_images\crop_0091.png
# C:\Users\user\Desktop\cropped_images\030_193\0225.png -> C:\Users\user\Desktop\selected_images\crop_0092.png
# C:\Users\user\Desktop\cropped_images\030_193\0250.png -> C:\Users\user\Desktop\selected_images\crop_0093.png
# C:\Users\user\Desktop\cropped_images\031_163\0400.png -> C:\Users\user\Desktop\selected_images\crop_0094.png
# C:\Users\user\Desktop\cropped_images\031_163\0425.png -> C:\Users\user\Desktop\selected_images\crop_0095.png
# C:\Users\user\Desktop\cropped_images\031_163\0450.png -> C:\Users\user\Desktop\selected_images\crop_0096.png
# C:\Users\user\Desktop\cropped_images\032_944\0225.png -> C:\Users\user\Desktop\selected_images\crop_0097.png
# C:\Users\user\Desktop\cropped_images\032_944\0250.png -> C:\Users\user\Desktop\selected_images\crop_0098.png
# C:\Users\user\Desktop\cropped_images\032_944\0275.png -> C:\Users\user\Desktop\selected_images\crop_0099.png
# C:\Users\user\Desktop\cropped_images\033_097\0725.png -> C:\Users\user\Desktop\selected_images\crop_0100.png
# C:\Users\user\Desktop\cropped_images\033_097\0750.png -> C:\Users\user\Desktop\selected_images\crop_0101.png
# C:\Users\user\Desktop\cropped_images\033_097\0775.png -> C:\Users\user\Desktop\selected_images\crop_0102.png
# C:\Users\user\Desktop\cropped_images\034_590\0325.png -> C:\Users\user\Desktop\selected_images\crop_0103.png
# C:\Users\user\Desktop\cropped_images\034_590\0350.png -> C:\Users\user\Desktop\selected_images\crop_0104.png
# C:\Users\user\Desktop\cropped_images\034_590\0375.png -> C:\Users\user\Desktop\selected_images\crop_0105.png
# C:\Users\user\Desktop\cropped_images\035_036\0325.png -> C:\Users\user\Desktop\selected_images\crop_0106.png
# C:\Users\user\Desktop\cropped_images\035_036\0350.png -> C:\Users\user\Desktop\selected_images\crop_0107.png
# C:\Users\user\Desktop\cropped_images\035_036\0375.png -> C:\Users\user\Desktop\selected_images\crop_0108.png
# C:\Users\user\Desktop\cropped_images\036_035\0250.png -> C:\Users\user\Desktop\selected_images\crop_0109.png
# C:\Users\user\Desktop\cropped_images\036_035\0275.png -> C:\Users\user\Desktop\selected_images\crop_0110.png
# C:\Users\user\Desktop\cropped_images\036_035\0300.png -> C:\Users\user\Desktop\selected_images\crop_0111.png
# C:\Users\user\Desktop\cropped_images\037_072\0375.png -> C:\Users\user\Desktop\selected_images\crop_0112.png
# C:\Users\user\Desktop\cropped_images\037_072\0400.png -> C:\Users\user\Desktop\selected_images\crop_0113.png
# C:\Users\user\Desktop\cropped_images\037_072\0425.png -> C:\Users\user\Desktop\selected_images\crop_0114.png
# C:\Users\user\Desktop\cropped_images\038_125\0225.png -> C:\Users\user\Desktop\selected_images\crop_0115.png
# C:\Users\user\Desktop\cropped_images\038_125\0250.png -> C:\Users\user\Desktop\selected_images\crop_0116.png
# C:\Users\user\Desktop\cropped_images\038_125\0275.png -> C:\Users\user\Desktop\selected_images\crop_0117.png
# C:\Users\user\Desktop\cropped_images\039_058\0525.png -> C:\Users\user\Desktop\selected_images\crop_0118.png
# C:\Users\user\Desktop\cropped_images\039_058\0550.png -> C:\Users\user\Desktop\selected_images\crop_0119.png
# C:\Users\user\Desktop\cropped_images\039_058\0575.png -> C:\Users\user\Desktop\selected_images\crop_0120.png
# C:\Users\user\Desktop\cropped_images\040_997\0450.png -> C:\Users\user\Desktop\selected_images\crop_0121.png
# C:\Users\user\Desktop\cropped_images\040_997\0475.png -> C:\Users\user\Desktop\selected_images\crop_0122.png
# C:\Users\user\Desktop\cropped_images\040_997\0500.png -> C:\Users\user\Desktop\selected_images\crop_0123.png
# C:\Users\user\Desktop\cropped_images\041_063\0250.png -> C:\Users\user\Desktop\selected_images\crop_0124.png
# C:\Users\user\Desktop\cropped_images\041_063\0275.png -> C:\Users\user\Desktop\selected_images\crop_0125.png
# C:\Users\user\Desktop\cropped_images\041_063\0300.png -> C:\Users\user\Desktop\selected_images\crop_0126.png
# C:\Users\user\Desktop\cropped_images\042_084\0250.png -> C:\Users\user\Desktop\selected_images\crop_0127.png
# C:\Users\user\Desktop\cropped_images\042_084\0275.png -> C:\Users\user\Desktop\selected_images\crop_0128.png
# C:\Users\user\Desktop\cropped_images\042_084\0300.png -> C:\Users\user\Desktop\selected_images\crop_0129.png
# C:\Users\user\Desktop\cropped_images\043_110\0400.png -> C:\Users\user\Desktop\selected_images\crop_0130.png
# C:\Users\user\Desktop\cropped_images\043_110\0425.png -> C:\Users\user\Desktop\selected_images\crop_0131.png
# C:\Users\user\Desktop\cropped_images\043_110\0450.png -> C:\Users\user\Desktop\selected_images\crop_0132.png
# C:\Users\user\Desktop\cropped_images\044_945\0250.png -> C:\Users\user\Desktop\selected_images\crop_0133.png
# C:\Users\user\Desktop\cropped_images\044_945\0275.png -> C:\Users\user\Desktop\selected_images\crop_0134.png
# C:\Users\user\Desktop\cropped_images\044_945\0300.png -> C:\Users\user\Desktop\selected_images\crop_0135.png
# C:\Users\user\Desktop\cropped_images\045_889\0250.png -> C:\Users\user\Desktop\selected_images\crop_0136.png
# C:\Users\user\Desktop\cropped_images\045_889\0275.png -> C:\Users\user\Desktop\selected_images\crop_0137.png
# C:\Users\user\Desktop\cropped_images\045_889\0300.png -> C:\Users\user\Desktop\selected_images\crop_0138.png
# C:\Users\user\Desktop\cropped_images\046_904\0425.png -> C:\Users\user\Desktop\selected_images\crop_0139.png
# C:\Users\user\Desktop\cropped_images\046_904\0450.png -> C:\Users\user\Desktop\selected_images\crop_0140.png
# C:\Users\user\Desktop\cropped_images\046_904\0475.png -> C:\Users\user\Desktop\selected_images\crop_0141.png
# C:\Users\user\Desktop\cropped_images\047_862\0225.png -> C:\Users\user\Desktop\selected_images\crop_0142.png
# C:\Users\user\Desktop\cropped_images\047_862\0250.png -> C:\Users\user\Desktop\selected_images\crop_0143.png
# C:\Users\user\Desktop\cropped_images\047_862\0275.png -> C:\Users\user\Desktop\selected_images\crop_0144.png
# C:\Users\user\Desktop\cropped_images\048_029\0400.png -> C:\Users\user\Desktop\selected_images\crop_0145.png
# C:\Users\user\Desktop\cropped_images\048_029\0425.png -> C:\Users\user\Desktop\selected_images\crop_0146.png
# C:\Users\user\Desktop\cropped_images\048_029\0450.png -> C:\Users\user\Desktop\selected_images\crop_0147.png
# C:\Users\user\Desktop\cropped_images\049_946\0275.png -> C:\Users\user\Desktop\selected_images\crop_0148.png
# C:\Users\user\Desktop\cropped_images\049_946\0300.png -> C:\Users\user\Desktop\selected_images\crop_0149.png
# C:\Users\user\Desktop\cropped_images\049_946\0325.png -> C:\Users\user\Desktop\selected_images\crop_0150.png
# C:\Users\user\Desktop\cropped_images\050_059\0450.png -> C:\Users\user\Desktop\selected_images\crop_0151.png
# C:\Users\user\Desktop\cropped_images\050_059\0475.png -> C:\Users\user\Desktop\selected_images\crop_0152.png
# C:\Users\user\Desktop\cropped_images\050_059\0500.png -> C:\Users\user\Desktop\selected_images\crop_0153.png
# C:\Users\user\Desktop\cropped_images\051_332\0625.png -> C:\Users\user\Desktop\selected_images\crop_0154.png
# C:\Users\user\Desktop\cropped_images\051_332\0650.png -> C:\Users\user\Desktop\selected_images\crop_0155.png
# C:\Users\user\Desktop\cropped_images\051_332\0675.png -> C:\Users\user\Desktop\selected_images\crop_0156.png
# C:\Users\user\Desktop\cropped_images\052_108\0225.png -> C:\Users\user\Desktop\selected_images\crop_0157.png
# C:\Users\user\Desktop\cropped_images\052_108\0250.png -> C:\Users\user\Desktop\selected_images\crop_0158.png
# C:\Users\user\Desktop\cropped_images\052_108\0275.png -> C:\Users\user\Desktop\selected_images\crop_0159.png
# C:\Users\user\Desktop\cropped_images\053_095\0325.png -> C:\Users\user\Desktop\selected_images\crop_0160.png
# C:\Users\user\Desktop\cropped_images\053_095\0350.png -> C:\Users\user\Desktop\selected_images\crop_0161.png
# C:\Users\user\Desktop\cropped_images\053_095\0375.png -> C:\Users\user\Desktop\selected_images\crop_0162.png
# C:\Users\user\Desktop\cropped_images\054_071\0275.png -> C:\Users\user\Desktop\selected_images\crop_0163.png
# C:\Users\user\Desktop\cropped_images\054_071\0300.png -> C:\Users\user\Desktop\selected_images\crop_0164.png
# C:\Users\user\Desktop\cropped_images\054_071\0325.png -> C:\Users\user\Desktop\selected_images\crop_0165.png
# C:\Users\user\Desktop\cropped_images\055_147\0300.png -> C:\Users\user\Desktop\selected_images\crop_0166.png
# C:\Users\user\Desktop\cropped_images\055_147\0325.png -> C:\Users\user\Desktop\selected_images\crop_0167.png
# C:\Users\user\Desktop\cropped_images\055_147\0350.png -> C:\Users\user\Desktop\selected_images\crop_0168.png
# C:\Users\user\Desktop\cropped_images\056_996\0275.png -> C:\Users\user\Desktop\selected_images\crop_0169.png
# C:\Users\user\Desktop\cropped_images\056_996\0300.png -> C:\Users\user\Desktop\selected_images\crop_0170.png
# C:\Users\user\Desktop\cropped_images\056_996\0325.png -> C:\Users\user\Desktop\selected_images\crop_0171.png
# C:\Users\user\Desktop\cropped_images\057_070\0350.png -> C:\Users\user\Desktop\selected_images\crop_0172.png
# C:\Users\user\Desktop\cropped_images\057_070\0375.png -> C:\Users\user\Desktop\selected_images\crop_0173.png
# C:\Users\user\Desktop\cropped_images\057_070\0400.png -> C:\Users\user\Desktop\selected_images\crop_0174.png
# C:\Users\user\Desktop\cropped_images\058_039\0575.png -> C:\Users\user\Desktop\selected_images\crop_0175.png
# C:\Users\user\Desktop\cropped_images\058_039\0600.png -> C:\Users\user\Desktop\selected_images\crop_0176.png
# C:\Users\user\Desktop\cropped_images\058_039\0625.png -> C:\Users\user\Desktop\selected_images\crop_0177.png
# C:\Users\user\Desktop\cropped_images\059_050\0625.png -> C:\Users\user\Desktop\selected_images\crop_0178.png
# C:\Users\user\Desktop\cropped_images\059_050\0650.png -> C:\Users\user\Desktop\selected_images\crop_0179.png
# C:\Users\user\Desktop\cropped_images\059_050\0675.png -> C:\Users\user\Desktop\selected_images\crop_0180.png
# C:\Users\user\Desktop\cropped_images\060_088\0750.png -> C:\Users\user\Desktop\selected_images\crop_0181.png
# C:\Users\user\Desktop\cropped_images\060_088\0775.png -> C:\Users\user\Desktop\selected_images\crop_0182.png
# C:\Users\user\Desktop\cropped_images\060_088\0800.png -> C:\Users\user\Desktop\selected_images\crop_0183.png
# C:\Users\user\Desktop\cropped_images\061_080\0250.png -> C:\Users\user\Desktop\selected_images\crop_0184.png
# C:\Users\user\Desktop\cropped_images\061_080\0275.png -> C:\Users\user\Desktop\selected_images\crop_0185.png
# C:\Users\user\Desktop\cropped_images\061_080\0300.png -> C:\Users\user\Desktop\selected_images\crop_0186.png
# C:\Users\user\Desktop\cropped_images\062_066\0325.png -> C:\Users\user\Desktop\selected_images\crop_0187.png
# C:\Users\user\Desktop\cropped_images\062_066\0350.png -> C:\Users\user\Desktop\selected_images\crop_0188.png
# C:\Users\user\Desktop\cropped_images\062_066\0375.png -> C:\Users\user\Desktop\selected_images\crop_0189.png
# C:\Users\user\Desktop\cropped_images\063_041\0850.png -> C:\Users\user\Desktop\selected_images\crop_0190.png
# C:\Users\user\Desktop\cropped_images\063_041\0875.png -> C:\Users\user\Desktop\selected_images\crop_0191.png
# C:\Users\user\Desktop\cropped_images\063_041\0900.png -> C:\Users\user\Desktop\selected_images\crop_0192.png
# C:\Users\user\Desktop\cropped_images\064_991\0325.png -> C:\Users\user\Desktop\selected_images\crop_0193.png
# C:\Users\user\Desktop\cropped_images\064_991\0350.png -> C:\Users\user\Desktop\selected_images\crop_0194.png
# C:\Users\user\Desktop\cropped_images\064_991\0375.png -> C:\Users\user\Desktop\selected_images\crop_0195.png
# C:\Users\user\Desktop\cropped_images\065_089\0350.png -> C:\Users\user\Desktop\selected_images\crop_0196.png
# C:\Users\user\Desktop\cropped_images\065_089\0375.png -> C:\Users\user\Desktop\selected_images\crop_0197.png
# C:\Users\user\Desktop\cropped_images\065_089\0400.png -> C:\Users\user\Desktop\selected_images\crop_0198.png
# C:\Users\user\Desktop\cropped_images\066_062\0350.png -> C:\Users\user\Desktop\selected_images\crop_0199.png
# C:\Users\user\Desktop\cropped_images\066_062\0375.png -> C:\Users\user\Desktop\selected_images\crop_0200.png
# C:\Users\user\Desktop\cropped_images\066_062\0400.png -> C:\Users\user\Desktop\selected_images\crop_0201.png
# C:\Users\user\Desktop\cropped_images\067_025\0450.png -> C:\Users\user\Desktop\selected_images\crop_0202.png
# C:\Users\user\Desktop\cropped_images\067_025\0475.png -> C:\Users\user\Desktop\selected_images\crop_0203.png
# C:\Users\user\Desktop\cropped_images\067_025\0500.png -> C:\Users\user\Desktop\selected_images\crop_0204.png
# C:\Users\user\Desktop\cropped_images\068_028\0325.png -> C:\Users\user\Desktop\selected_images\crop_0205.png
# C:\Users\user\Desktop\cropped_images\068_028\0350.png -> C:\Users\user\Desktop\selected_images\crop_0206.png
# C:\Users\user\Desktop\cropped_images\068_028\0375.png -> C:\Users\user\Desktop\selected_images\crop_0207.png
# C:\Users\user\Desktop\cropped_images\069_961\0675.png -> C:\Users\user\Desktop\selected_images\crop_0208.png
# C:\Users\user\Desktop\cropped_images\069_961\0700.png -> C:\Users\user\Desktop\selected_images\crop_0209.png
# C:\Users\user\Desktop\cropped_images\069_961\0725.png -> C:\Users\user\Desktop\selected_images\crop_0210.png
# C:\Users\user\Desktop\cropped_images\070_057\0275.png -> C:\Users\user\Desktop\selected_images\crop_0211.png
# C:\Users\user\Desktop\cropped_images\070_057\0300.png -> C:\Users\user\Desktop\selected_images\crop_0212.png
# C:\Users\user\Desktop\cropped_images\070_057\0325.png -> C:\Users\user\Desktop\selected_images\crop_0213.png
# C:\Users\user\Desktop\cropped_images\071_054\0375.png -> C:\Users\user\Desktop\selected_images\crop_0214.png
# C:\Users\user\Desktop\cropped_images\071_054\0400.png -> C:\Users\user\Desktop\selected_images\crop_0215.png
# C:\Users\user\Desktop\cropped_images\071_054\0425.png -> C:\Users\user\Desktop\selected_images\crop_0216.png
# C:\Users\user\Desktop\cropped_images\072_037\0225.png -> C:\Users\user\Desktop\selected_images\crop_0217.png
# C:\Users\user\Desktop\cropped_images\072_037\0250.png -> C:\Users\user\Desktop\selected_images\crop_0218.png
# C:\Users\user\Desktop\cropped_images\072_037\0275.png -> C:\Users\user\Desktop\selected_images\crop_0219.png
# C:\Users\user\Desktop\cropped_images\073_024\0625.png -> C:\Users\user\Desktop\selected_images\crop_0220.png
# C:\Users\user\Desktop\cropped_images\073_024\0650.png -> C:\Users\user\Desktop\selected_images\crop_0221.png
# C:\Users\user\Desktop\cropped_images\073_024\0675.png -> C:\Users\user\Desktop\selected_images\crop_0222.png
# C:\Users\user\Desktop\cropped_images\074_825\0250.png -> C:\Users\user\Desktop\selected_images\crop_0223.png
# C:\Users\user\Desktop\cropped_images\074_825\0275.png -> C:\Users\user\Desktop\selected_images\crop_0224.png
# C:\Users\user\Desktop\cropped_images\074_825\0300.png -> C:\Users\user\Desktop\selected_images\crop_0225.png
# C:\Users\user\Desktop\cropped_images\075_977\0500.png -> C:\Users\user\Desktop\selected_images\crop_0226.png
# C:\Users\user\Desktop\cropped_images\075_977\0525.png -> C:\Users\user\Desktop\selected_images\crop_0227.png
# C:\Users\user\Desktop\cropped_images\075_977\0550.png -> C:\Users\user\Desktop\selected_images\crop_0228.png
# C:\Users\user\Desktop\cropped_images\076_079\0250.png -> C:\Users\user\Desktop\selected_images\crop_0229.png
# C:\Users\user\Desktop\cropped_images\076_079\0275.png -> C:\Users\user\Desktop\selected_images\crop_0230.png
# C:\Users\user\Desktop\cropped_images\076_079\0300.png -> C:\Users\user\Desktop\selected_images\crop_0231.png
# C:\Users\user\Desktop\cropped_images\077_100\0525.png -> C:\Users\user\Desktop\selected_images\crop_0232.png
# C:\Users\user\Desktop\cropped_images\077_100\0550.png -> C:\Users\user\Desktop\selected_images\crop_0233.png
# C:\Users\user\Desktop\cropped_images\077_100\0575.png -> C:\Users\user\Desktop\selected_images\crop_0234.png
# C:\Users\user\Desktop\cropped_images\078_955\0425.png -> C:\Users\user\Desktop\selected_images\crop_0235.png
# C:\Users\user\Desktop\cropped_images\078_955\0450.png -> C:\Users\user\Desktop\selected_images\crop_0236.png
# C:\Users\user\Desktop\cropped_images\078_955\0475.png -> C:\Users\user\Desktop\selected_images\crop_0237.png
# C:\Users\user\Desktop\cropped_images\079_076\0325.png -> C:\Users\user\Desktop\selected_images\crop_0238.png
# C:\Users\user\Desktop\cropped_images\079_076\0350.png -> C:\Users\user\Desktop\selected_images\crop_0239.png
# C:\Users\user\Desktop\cropped_images\079_076\0375.png -> C:\Users\user\Desktop\selected_images\crop_0240.png
# C:\Users\user\Desktop\cropped_images\080_061\0400.png -> C:\Users\user\Desktop\selected_images\crop_0241.png
# C:\Users\user\Desktop\cropped_images\080_061\0425.png -> C:\Users\user\Desktop\selected_images\crop_0242.png
# C:\Users\user\Desktop\cropped_images\080_061\0450.png -> C:\Users\user\Desktop\selected_images\crop_0243.png
# C:\Users\user\Desktop\cropped_images\081_087\1075.png -> C:\Users\user\Desktop\selected_images\crop_0244.png
# C:\Users\user\Desktop\cropped_images\081_087\1100.png -> C:\Users\user\Desktop\selected_images\crop_0245.png
# C:\Users\user\Desktop\cropped_images\081_087\1125.png -> C:\Users\user\Desktop\selected_images\crop_0246.png
# C:\Users\user\Desktop\cropped_images\082_103\0225.png -> C:\Users\user\Desktop\selected_images\crop_0247.png
# C:\Users\user\Desktop\cropped_images\082_103\0250.png -> C:\Users\user\Desktop\selected_images\crop_0248.png
# C:\Users\user\Desktop\cropped_images\082_103\0275.png -> C:\Users\user\Desktop\selected_images\crop_0249.png
# C:\Users\user\Desktop\cropped_images\083_213\0450.png -> C:\Users\user\Desktop\selected_images\crop_0250.png
# C:\Users\user\Desktop\cropped_images\083_213\0475.png -> C:\Users\user\Desktop\selected_images\crop_0251.png
# C:\Users\user\Desktop\cropped_images\083_213\0500.png -> C:\Users\user\Desktop\selected_images\crop_0252.png
# C:\Users\user\Desktop\cropped_images\084_042\0275.png -> C:\Users\user\Desktop\selected_images\crop_0253.png
# C:\Users\user\Desktop\cropped_images\084_042\0300.png -> C:\Users\user\Desktop\selected_images\crop_0254.png
# C:\Users\user\Desktop\cropped_images\084_042\0325.png -> C:\Users\user\Desktop\selected_images\crop_0255.png
# C:\Users\user\Desktop\cropped_images\085_124\0250.png -> C:\Users\user\Desktop\selected_images\crop_0256.png
# C:\Users\user\Desktop\cropped_images\085_124\0275.png -> C:\Users\user\Desktop\selected_images\crop_0257.png
# C:\Users\user\Desktop\cropped_images\085_124\0300.png -> C:\Users\user\Desktop\selected_images\crop_0258.png
# C:\Users\user\Desktop\cropped_images\086_090\0850.png -> C:\Users\user\Desktop\selected_images\crop_0259.png
# C:\Users\user\Desktop\cropped_images\086_090\0875.png -> C:\Users\user\Desktop\selected_images\crop_0260.png
# C:\Users\user\Desktop\cropped_images\086_090\0900.png -> C:\Users\user\Desktop\selected_images\crop_0261.png
# C:\Users\user\Desktop\cropped_images\087_081\0225.png -> C:\Users\user\Desktop\selected_images\crop_0262.png
# C:\Users\user\Desktop\cropped_images\087_081\0250.png -> C:\Users\user\Desktop\selected_images\crop_0263.png
# C:\Users\user\Desktop\cropped_images\087_081\0275.png -> C:\Users\user\Desktop\selected_images\crop_0264.png
# C:\Users\user\Desktop\cropped_images\088_060\0575.png -> C:\Users\user\Desktop\selected_images\crop_0265.png
# C:\Users\user\Desktop\cropped_images\088_060\0600.png -> C:\Users\user\Desktop\selected_images\crop_0266.png
# C:\Users\user\Desktop\cropped_images\088_060\0625.png -> C:\Users\user\Desktop\selected_images\crop_0267.png
# C:\Users\user\Desktop\cropped_images\089_065\0675.png -> C:\Users\user\Desktop\selected_images\crop_0268.png
# C:\Users\user\Desktop\cropped_images\089_065\0700.png -> C:\Users\user\Desktop\selected_images\crop_0269.png
# C:\Users\user\Desktop\cropped_images\089_065\0725.png -> C:\Users\user\Desktop\selected_images\crop_0270.png
# C:\Users\user\Desktop\cropped_images\090_086\0600.png -> C:\Users\user\Desktop\selected_images\crop_0271.png
# C:\Users\user\Desktop\cropped_images\090_086\0625.png -> C:\Users\user\Desktop\selected_images\crop_0272.png
# C:\Users\user\Desktop\cropped_images\090_086\0650.png -> C:\Users\user\Desktop\selected_images\crop_0273.png
# C:\Users\user\Desktop\cropped_images\091_116\0550.png -> C:\Users\user\Desktop\selected_images\crop_0274.png
# C:\Users\user\Desktop\cropped_images\091_116\0575.png -> C:\Users\user\Desktop\selected_images\crop_0275.png
# C:\Users\user\Desktop\cropped_images\091_116\0600.png -> C:\Users\user\Desktop\selected_images\crop_0276.png
# C:\Users\user\Desktop\cropped_images\092_098\0375.png -> C:\Users\user\Desktop\selected_images\crop_0277.png
# C:\Users\user\Desktop\cropped_images\092_098\0400.png -> C:\Users\user\Desktop\selected_images\crop_0278.png
# C:\Users\user\Desktop\cropped_images\092_098\0425.png -> C:\Users\user\Desktop\selected_images\crop_0279.png
# C:\Users\user\Desktop\cropped_images\093_121\0225.png -> C:\Users\user\Desktop\selected_images\crop_0280.png
# C:\Users\user\Desktop\cropped_images\093_121\0250.png -> C:\Users\user\Desktop\selected_images\crop_0281.png
# C:\Users\user\Desktop\cropped_images\093_121\0275.png -> C:\Users\user\Desktop\selected_images\crop_0282.png
# C:\Users\user\Desktop\cropped_images\094_111\0475.png -> C:\Users\user\Desktop\selected_images\crop_0283.png
# C:\Users\user\Desktop\cropped_images\094_111\0500.png -> C:\Users\user\Desktop\selected_images\crop_0284.png
# C:\Users\user\Desktop\cropped_images\094_111\0525.png -> C:\Users\user\Desktop\selected_images\crop_0285.png
# C:\Users\user\Desktop\cropped_images\095_053\0925.png -> C:\Users\user\Desktop\selected_images\crop_0286.png
# C:\Users\user\Desktop\cropped_images\095_053\0950.png -> C:\Users\user\Desktop\selected_images\crop_0287.png
# C:\Users\user\Desktop\cropped_images\095_053\0975.png -> C:\Users\user\Desktop\selected_images\crop_0288.png
# C:\Users\user\Desktop\cropped_images\096_101\0425.png -> C:\Users\user\Desktop\selected_images\crop_0289.png
# C:\Users\user\Desktop\cropped_images\096_101\0450.png -> C:\Users\user\Desktop\selected_images\crop_0290.png
# C:\Users\user\Desktop\cropped_images\096_101\0475.png -> C:\Users\user\Desktop\selected_images\crop_0291.png
# C:\Users\user\Desktop\cropped_images\097_033\0400.png -> C:\Users\user\Desktop\selected_images\crop_0292.png
# C:\Users\user\Desktop\cropped_images\097_033\0425.png -> C:\Users\user\Desktop\selected_images\crop_0293.png
# C:\Users\user\Desktop\cropped_images\097_033\0450.png -> C:\Users\user\Desktop\selected_images\crop_0294.png
# C:\Users\user\Desktop\cropped_images\098_092\0200.png -> C:\Users\user\Desktop\selected_images\crop_0295.png
# C:\Users\user\Desktop\cropped_images\098_092\0225.png -> C:\Users\user\Desktop\selected_images\crop_0296.png
# C:\Users\user\Desktop\cropped_images\098_092\0250.png -> C:\Users\user\Desktop\selected_images\crop_0297.png
# C:\Users\user\Desktop\cropped_images\099_295\0525.png -> C:\Users\user\Desktop\selected_images\crop_0298.png
# C:\Users\user\Desktop\cropped_images\099_295\0550.png -> C:\Users\user\Desktop\selected_images\crop_0299.png
# C:\Users\user\Desktop\cropped_images\099_295\0575.png -> C:\Users\user\Desktop\selected_images\crop_0300.png
# C:\Users\user\Desktop\cropped_images\100_077\0325.png -> C:\Users\user\Desktop\selected_images\crop_0301.png
# C:\Users\user\Desktop\cropped_images\100_077\0350.png -> C:\Users\user\Desktop\selected_images\crop_0302.png
# C:\Users\user\Desktop\cropped_images\100_077\0375.png -> C:\Users\user\Desktop\selected_images\crop_0303.png
# C:\Users\user\Desktop\cropped_images\101_096\1050.png -> C:\Users\user\Desktop\selected_images\crop_0304.png
# C:\Users\user\Desktop\cropped_images\101_096\1075.png -> C:\Users\user\Desktop\selected_images\crop_0305.png
# C:\Users\user\Desktop\cropped_images\101_096\1100.png -> C:\Users\user\Desktop\selected_images\crop_0306.png
# C:\Users\user\Desktop\cropped_images\102_114\0300.png -> C:\Users\user\Desktop\selected_images\crop_0307.png
# C:\Users\user\Desktop\cropped_images\102_114\0325.png -> C:\Users\user\Desktop\selected_images\crop_0308.png
# C:\Users\user\Desktop\cropped_images\102_114\0350.png -> C:\Users\user\Desktop\selected_images\crop_0309.png
# C:\Users\user\Desktop\cropped_images\103_082\0500.png -> C:\Users\user\Desktop\selected_images\crop_0310.png
# C:\Users\user\Desktop\cropped_images\103_082\0525.png -> C:\Users\user\Desktop\selected_images\crop_0311.png
# C:\Users\user\Desktop\cropped_images\103_082\0550.png -> C:\Users\user\Desktop\selected_images\crop_0312.png
# C:\Users\user\Desktop\cropped_images\104_126\0375.png -> C:\Users\user\Desktop\selected_images\crop_0313.png
# C:\Users\user\Desktop\cropped_images\104_126\0400.png -> C:\Users\user\Desktop\selected_images\crop_0314.png
# C:\Users\user\Desktop\cropped_images\104_126\0425.png -> C:\Users\user\Desktop\selected_images\crop_0315.png
# C:\Users\user\Desktop\cropped_images\105_180\0175.png -> C:\Users\user\Desktop\selected_images\crop_0316.png
# C:\Users\user\Desktop\cropped_images\105_180\0200.png -> C:\Users\user\Desktop\selected_images\crop_0317.png
# C:\Users\user\Desktop\cropped_images\105_180\0250.png -> C:\Users\user\Desktop\selected_images\crop_0318.png
# C:\Users\user\Desktop\cropped_images\106_198\0275.png -> C:\Users\user\Desktop\selected_images\crop_0319.png
# C:\Users\user\Desktop\cropped_images\106_198\0300.png -> C:\Users\user\Desktop\selected_images\crop_0320.png
# C:\Users\user\Desktop\cropped_images\106_198\0325.png -> C:\Users\user\Desktop\selected_images\crop_0321.png
# C:\Users\user\Desktop\cropped_images\107_109\0475.png -> C:\Users\user\Desktop\selected_images\crop_0322.png
# C:\Users\user\Desktop\cropped_images\107_109\0500.png -> C:\Users\user\Desktop\selected_images\crop_0323.png
# C:\Users\user\Desktop\cropped_images\107_109\0525.png -> C:\Users\user\Desktop\selected_images\crop_0324.png
# C:\Users\user\Desktop\cropped_images\108_052\0200.png -> C:\Users\user\Desktop\selected_images\crop_0325.png
# C:\Users\user\Desktop\cropped_images\108_052\0225.png -> C:\Users\user\Desktop\selected_images\crop_0326.png
# C:\Users\user\Desktop\cropped_images\108_052\0250.png -> C:\Users\user\Desktop\selected_images\crop_0327.png
# C:\Users\user\Desktop\cropped_images\109_107\0200.png -> C:\Users\user\Desktop\selected_images\crop_0328.png
# C:\Users\user\Desktop\cropped_images\109_107\0225.png -> C:\Users\user\Desktop\selected_images\crop_0329.png
# C:\Users\user\Desktop\cropped_images\109_107\0250.png -> C:\Users\user\Desktop\selected_images\crop_0330.png
# C:\Users\user\Desktop\cropped_images\110_043\0475.png -> C:\Users\user\Desktop\selected_images\crop_0331.png
# C:\Users\user\Desktop\cropped_images\110_043\0500.png -> C:\Users\user\Desktop\selected_images\crop_0332.png
# C:\Users\user\Desktop\cropped_images\110_043\0525.png -> C:\Users\user\Desktop\selected_images\crop_0333.png
# C:\Users\user\Desktop\cropped_images\111_094\0350.png -> C:\Users\user\Desktop\selected_images\crop_0334.png
# C:\Users\user\Desktop\cropped_images\111_094\0375.png -> C:\Users\user\Desktop\selected_images\crop_0335.png
# C:\Users\user\Desktop\cropped_images\111_094\0400.png -> C:\Users\user\Desktop\selected_images\crop_0336.png
# C:\Users\user\Desktop\cropped_images\112_892\0250.png -> C:\Users\user\Desktop\selected_images\crop_0337.png
# C:\Users\user\Desktop\cropped_images\112_892\0350.png -> C:\Users\user\Desktop\selected_images\crop_0338.png
# C:\Users\user\Desktop\cropped_images\112_892\0375.png -> C:\Users\user\Desktop\selected_images\crop_0339.png
# C:\Users\user\Desktop\cropped_images\113_983\0750.png -> C:\Users\user\Desktop\selected_images\crop_0340.png
# C:\Users\user\Desktop\cropped_images\113_983\0775.png -> C:\Users\user\Desktop\selected_images\crop_0341.png
# C:\Users\user\Desktop\cropped_images\113_983\0800.png -> C:\Users\user\Desktop\selected_images\crop_0342.png
# C:\Users\user\Desktop\cropped_images\114_102\1175.png -> C:\Users\user\Desktop\selected_images\crop_0343.png
# C:\Users\user\Desktop\cropped_images\114_102\1200.png -> C:\Users\user\Desktop\selected_images\crop_0344.png
# C:\Users\user\Desktop\cropped_images\114_102\1225.png -> C:\Users\user\Desktop\selected_images\crop_0345.png
# C:\Users\user\Desktop\cropped_images\115_939\0225.png -> C:\Users\user\Desktop\selected_images\crop_0346.png
# C:\Users\user\Desktop\cropped_images\115_939\0250.png -> C:\Users\user\Desktop\selected_images\crop_0347.png
# C:\Users\user\Desktop\cropped_images\115_939\0275.png -> C:\Users\user\Desktop\selected_images\crop_0348.png
# C:\Users\user\Desktop\cropped_images\116_091\0250.png -> C:\Users\user\Desktop\selected_images\crop_0349.png
# C:\Users\user\Desktop\cropped_images\116_091\0275.png -> C:\Users\user\Desktop\selected_images\crop_0350.png
# C:\Users\user\Desktop\cropped_images\116_091\0300.png -> C:\Users\user\Desktop\selected_images\crop_0351.png
# C:\Users\user\Desktop\cropped_images\117_217\0450.png -> C:\Users\user\Desktop\selected_images\crop_0352.png
# C:\Users\user\Desktop\cropped_images\117_217\0475.png -> C:\Users\user\Desktop\selected_images\crop_0353.png
# C:\Users\user\Desktop\cropped_images\117_217\0500.png -> C:\Users\user\Desktop\selected_images\crop_0354.png
# C:\Users\user\Desktop\cropped_images\118_120\0275.png -> C:\Users\user\Desktop\selected_images\crop_0355.png
# C:\Users\user\Desktop\cropped_images\118_120\0300.png -> C:\Users\user\Desktop\selected_images\crop_0356.png
# C:\Users\user\Desktop\cropped_images\118_120\0325.png -> C:\Users\user\Desktop\selected_images\crop_0357.png
# C:\Users\user\Desktop\cropped_images\119_123\0425.png -> C:\Users\user\Desktop\selected_images\crop_0358.png
# C:\Users\user\Desktop\cropped_images\119_123\0450.png -> C:\Users\user\Desktop\selected_images\crop_0359.png
# C:\Users\user\Desktop\cropped_images\119_123\0475.png -> C:\Users\user\Desktop\selected_images\crop_0360.png
# C:\Users\user\Desktop\cropped_images\120_118\0325.png -> C:\Users\user\Desktop\selected_images\crop_0361.png
# C:\Users\user\Desktop\cropped_images\120_118\0350.png -> C:\Users\user\Desktop\selected_images\crop_0362.png
# C:\Users\user\Desktop\cropped_images\120_118\0375.png -> C:\Users\user\Desktop\selected_images\crop_0363.png
# C:\Users\user\Desktop\cropped_images\121_093\0475.png -> C:\Users\user\Desktop\selected_images\crop_0364.png
# C:\Users\user\Desktop\cropped_images\121_093\0500.png -> C:\Users\user\Desktop\selected_images\crop_0365.png
# C:\Users\user\Desktop\cropped_images\121_093\0525.png -> C:\Users\user\Desktop\selected_images\crop_0366.png
# C:\Users\user\Desktop\cropped_images\122_144\0225.png -> C:\Users\user\Desktop\selected_images\crop_0367.png
# C:\Users\user\Desktop\cropped_images\122_144\0250.png -> C:\Users\user\Desktop\selected_images\crop_0368.png
# C:\Users\user\Desktop\cropped_images\122_144\0275.png -> C:\Users\user\Desktop\selected_images\crop_0369.png
# C:\Users\user\Desktop\cropped_images\123_119\0425.png -> C:\Users\user\Desktop\selected_images\crop_0370.png
# C:\Users\user\Desktop\cropped_images\123_119\0450.png -> C:\Users\user\Desktop\selected_images\crop_0371.png
# C:\Users\user\Desktop\cropped_images\123_119\0475.png -> C:\Users\user\Desktop\selected_images\crop_0372.png
# C:\Users\user\Desktop\cropped_images\124_085\0225.png -> C:\Users\user\Desktop\selected_images\crop_0373.png
# C:\Users\user\Desktop\cropped_images\124_085\0250.png -> C:\Users\user\Desktop\selected_images\crop_0374.png
# C:\Users\user\Desktop\cropped_images\124_085\0275.png -> C:\Users\user\Desktop\selected_images\crop_0375.png
# C:\Users\user\Desktop\cropped_images\125_038\0400.png -> C:\Users\user\Desktop\selected_images\crop_0376.png
# C:\Users\user\Desktop\cropped_images\125_038\0425.png -> C:\Users\user\Desktop\selected_images\crop_0377.png
# C:\Users\user\Desktop\cropped_images\125_038\0450.png -> C:\Users\user\Desktop\selected_images\crop_0378.png
# C:\Users\user\Desktop\cropped_images\126_104\0250.png -> C:\Users\user\Desktop\selected_images\crop_0379.png
# C:\Users\user\Desktop\cropped_images\126_104\0275.png -> C:\Users\user\Desktop\selected_images\crop_0380.png
# C:\Users\user\Desktop\cropped_images\126_104\0300.png -> C:\Users\user\Desktop\selected_images\crop_0381.png
# C:\Users\user\Desktop\cropped_images\127_129\0775.png -> C:\Users\user\Desktop\selected_images\crop_0382.png
# C:\Users\user\Desktop\cropped_images\127_129\0800.png -> C:\Users\user\Desktop\selected_images\crop_0383.png
# C:\Users\user\Desktop\cropped_images\127_129\0825.png -> C:\Users\user\Desktop\selected_images\crop_0384.png
# C:\Users\user\Desktop\cropped_images\128_896\0625.png -> C:\Users\user\Desktop\selected_images\crop_0385.png
# C:\Users\user\Desktop\cropped_images\128_896\0650.png -> C:\Users\user\Desktop\selected_images\crop_0386.png
# C:\Users\user\Desktop\cropped_images\128_896\0675.png -> C:\Users\user\Desktop\selected_images\crop_0387.png
# C:\Users\user\Desktop\cropped_images\129_127\0250.png -> C:\Users\user\Desktop\selected_images\crop_0388.png
# C:\Users\user\Desktop\cropped_images\129_127\0275.png -> C:\Users\user\Desktop\selected_images\crop_0389.png
# C:\Users\user\Desktop\cropped_images\129_127\0300.png -> C:\Users\user\Desktop\selected_images\crop_0390.png
# C:\Users\user\Desktop\cropped_images\130_139\0575.png -> C:\Users\user\Desktop\selected_images\crop_0391.png
# C:\Users\user\Desktop\cropped_images\130_139\0600.png -> C:\Users\user\Desktop\selected_images\crop_0392.png
# C:\Users\user\Desktop\cropped_images\130_139\0625.png -> C:\Users\user\Desktop\selected_images\crop_0393.png
# C:\Users\user\Desktop\cropped_images\131_518\0200.png -> C:\Users\user\Desktop\selected_images\crop_0394.png
# C:\Users\user\Desktop\cropped_images\131_518\0225.png -> C:\Users\user\Desktop\selected_images\crop_0395.png
# C:\Users\user\Desktop\cropped_images\131_518\0250.png -> C:\Users\user\Desktop\selected_images\crop_0396.png
# C:\Users\user\Desktop\cropped_images\132_007\0325.png -> C:\Users\user\Desktop\selected_images\crop_0397.png
# C:\Users\user\Desktop\cropped_images\132_007\0350.png -> C:\Users\user\Desktop\selected_images\crop_0398.png
# C:\Users\user\Desktop\cropped_images\132_007\0375.png -> C:\Users\user\Desktop\selected_images\crop_0399.png
# C:\Users\user\Desktop\cropped_images\133_148\0675.png -> C:\Users\user\Desktop\selected_images\crop_0400.png
# C:\Users\user\Desktop\cropped_images\133_148\0700.png -> C:\Users\user\Desktop\selected_images\crop_0401.png
# C:\Users\user\Desktop\cropped_images\133_148\0725.png -> C:\Users\user\Desktop\selected_images\crop_0402.png
# C:\Users\user\Desktop\cropped_images\134_192\0250.png -> C:\Users\user\Desktop\selected_images\crop_0403.png
# C:\Users\user\Desktop\cropped_images\134_192\0275.png -> C:\Users\user\Desktop\selected_images\crop_0404.png
# C:\Users\user\Desktop\cropped_images\134_192\0300.png -> C:\Users\user\Desktop\selected_images\crop_0405.png
# C:\Users\user\Desktop\cropped_images\135_880\0250.png -> C:\Users\user\Desktop\selected_images\crop_0406.png
# C:\Users\user\Desktop\cropped_images\135_880\0275.png -> C:\Users\user\Desktop\selected_images\crop_0407.png
# C:\Users\user\Desktop\cropped_images\135_880\0300.png -> C:\Users\user\Desktop\selected_images\crop_0408.png
# C:\Users\user\Desktop\cropped_images\136_285\0525.png -> C:\Users\user\Desktop\selected_images\crop_0409.png
# C:\Users\user\Desktop\cropped_images\136_285\0550.png -> C:\Users\user\Desktop\selected_images\crop_0410.png
# C:\Users\user\Desktop\cropped_images\136_285\0575.png -> C:\Users\user\Desktop\selected_images\crop_0411.png
# C:\Users\user\Desktop\cropped_images\137_165\0525.png -> C:\Users\user\Desktop\selected_images\crop_0412.png
# C:\Users\user\Desktop\cropped_images\137_165\0550.png -> C:\Users\user\Desktop\selected_images\crop_0413.png
# C:\Users\user\Desktop\cropped_images\137_165\0575.png -> C:\Users\user\Desktop\selected_images\crop_0414.png
# C:\Users\user\Desktop\cropped_images\138_142\0325.png -> C:\Users\user\Desktop\selected_images\crop_0415.png
# C:\Users\user\Desktop\cropped_images\138_142\0350.png -> C:\Users\user\Desktop\selected_images\crop_0416.png
# C:\Users\user\Desktop\cropped_images\138_142\0375.png -> C:\Users\user\Desktop\selected_images\crop_0417.png
# C:\Users\user\Desktop\cropped_images\139_130\0300.png -> C:\Users\user\Desktop\selected_images\crop_0418.png
# C:\Users\user\Desktop\cropped_images\139_130\0325.png -> C:\Users\user\Desktop\selected_images\crop_0419.png
# C:\Users\user\Desktop\cropped_images\139_130\0350.png -> C:\Users\user\Desktop\selected_images\crop_0420.png
# C:\Users\user\Desktop\cropped_images\140_143\0400.png -> C:\Users\user\Desktop\selected_images\crop_0421.png
# C:\Users\user\Desktop\cropped_images\140_143\0425.png -> C:\Users\user\Desktop\selected_images\crop_0422.png
# C:\Users\user\Desktop\cropped_images\140_143\0450.png -> C:\Users\user\Desktop\selected_images\crop_0423.png
# C:\Users\user\Desktop\cropped_images\141_161\0425.png -> C:\Users\user\Desktop\selected_images\crop_0424.png
# C:\Users\user\Desktop\cropped_images\141_161\0450.png -> C:\Users\user\Desktop\selected_images\crop_0425.png
# C:\Users\user\Desktop\cropped_images\141_161\0475.png -> C:\Users\user\Desktop\selected_images\crop_0426.png
# C:\Users\user\Desktop\cropped_images\142_138\0875.png -> C:\Users\user\Desktop\selected_images\crop_0427.png
# C:\Users\user\Desktop\cropped_images\142_138\0900.png -> C:\Users\user\Desktop\selected_images\crop_0428.png
# C:\Users\user\Desktop\cropped_images\142_138\0925.png -> C:\Users\user\Desktop\selected_images\crop_0429.png
# C:\Users\user\Desktop\cropped_images\143_140\0325.png -> C:\Users\user\Desktop\selected_images\crop_0430.png
# C:\Users\user\Desktop\cropped_images\143_140\0350.png -> C:\Users\user\Desktop\selected_images\crop_0431.png
# C:\Users\user\Desktop\cropped_images\143_140\0375.png -> C:\Users\user\Desktop\selected_images\crop_0432.png
# C:\Users\user\Desktop\cropped_images\144_122\0250.png -> C:\Users\user\Desktop\selected_images\crop_0433.png
# C:\Users\user\Desktop\cropped_images\144_122\0275.png -> C:\Users\user\Desktop\selected_images\crop_0434.png
# C:\Users\user\Desktop\cropped_images\144_122\0300.png -> C:\Users\user\Desktop\selected_images\crop_0435.png
# C:\Users\user\Desktop\cropped_images\145_299\0375.png -> C:\Users\user\Desktop\selected_images\crop_0436.png
# C:\Users\user\Desktop\cropped_images\145_299\0400.png -> C:\Users\user\Desktop\selected_images\crop_0437.png
# C:\Users\user\Desktop\cropped_images\145_299\0425.png -> C:\Users\user\Desktop\selected_images\crop_0438.png
# C:\Users\user\Desktop\cropped_images\146_256\0925.png -> C:\Users\user\Desktop\selected_images\crop_0439.png
# C:\Users\user\Desktop\cropped_images\146_256\0950.png -> C:\Users\user\Desktop\selected_images\crop_0440.png
# ...
# C:\Users\user\Desktop\cropped_images\951_947\1125.png -> C:\Users\user\Desktop\selected_images\crop_2842.png
# C:\Users\user\Desktop\cropped_images\951_947\1150.png -> C:\Users\user\Desktop\selected_images\crop_2843.png
# C:\Users\user\Desktop\cropped_images\952_882\0600.png -> C:\Users\user\Desktop\selected_images\crop_2844.png
# C:\Users\user\Desktop\cropped_images\952_882\0625.png -> C:\Users\user\Desktop\selected_images\crop_2845.png
# C:\Users\user\Desktop\cropped_images\952_882\0650.png -> C:\Users\user\Desktop\selected_images\crop_2846.png
# C:\Users\user\Desktop\cropped_images\953_974\0275.png -> C:\Users\user\Desktop\selected_images\crop_2847.png
# C:\Users\user\Desktop\cropped_images\953_974\0300.png -> C:\Users\user\Desktop\selected_images\crop_2848.png
# C:\Users\user\Desktop\cropped_images\953_974\0325.png -> C:\Users\user\Desktop\selected_images\crop_2849.png
# C:\Users\user\Desktop\cropped_images\954_976\0300.png -> C:\Users\user\Desktop\selected_images\crop_2850.png
# C:\Users\user\Desktop\cropped_images\954_976\0325.png -> C:\Users\user\Desktop\selected_images\crop_2851.png
# C:\Users\user\Desktop\cropped_images\954_976\0350.png -> C:\Users\user\Desktop\selected_images\crop_2852.png
# C:\Users\user\Desktop\cropped_images\955_078\0450.png -> C:\Users\user\Desktop\selected_images\crop_2853.png
# C:\Users\user\Desktop\cropped_images\955_078\0475.png -> C:\Users\user\Desktop\selected_images\crop_2854.png
# C:\Users\user\Desktop\cropped_images\955_078\0500.png -> C:\Users\user\Desktop\selected_images\crop_2855.png
# C:\Users\user\Desktop\cropped_images\956_958\0450.png -> C:\Users\user\Desktop\selected_images\crop_2856.png
# C:\Users\user\Desktop\cropped_images\956_958\0475.png -> C:\Users\user\Desktop\selected_images\crop_2857.png
# C:\Users\user\Desktop\cropped_images\956_958\0500.png -> C:\Users\user\Desktop\selected_images\crop_2858.png
# C:\Users\user\Desktop\cropped_images\957_959\0325.png -> C:\Users\user\Desktop\selected_images\crop_2859.png
# C:\Users\user\Desktop\cropped_images\957_959\0350.png -> C:\Users\user\Desktop\selected_images\crop_2860.png
# C:\Users\user\Desktop\cropped_images\957_959\0375.png -> C:\Users\user\Desktop\selected_images\crop_2861.png
# C:\Users\user\Desktop\cropped_images\958_956\0300.png -> C:\Users\user\Desktop\selected_images\crop_2862.png
# C:\Users\user\Desktop\cropped_images\958_956\0325.png -> C:\Users\user\Desktop\selected_images\crop_2863.png
# C:\Users\user\Desktop\cropped_images\958_956\0350.png -> C:\Users\user\Desktop\selected_images\crop_2864.png
# C:\Users\user\Desktop\cropped_images\959_957\0400.png -> C:\Users\user\Desktop\selected_images\crop_2865.png
# C:\Users\user\Desktop\cropped_images\959_957\0425.png -> C:\Users\user\Desktop\selected_images\crop_2866.png
# C:\Users\user\Desktop\cropped_images\959_957\0450.png -> C:\Users\user\Desktop\selected_images\crop_2867.png
# C:\Users\user\Desktop\cropped_images\960_999\0250.png -> C:\Users\user\Desktop\selected_images\crop_2868.png
# C:\Users\user\Desktop\cropped_images\960_999\0275.png -> C:\Users\user\Desktop\selected_images\crop_2869.png
# C:\Users\user\Desktop\cropped_images\960_999\0300.png -> C:\Users\user\Desktop\selected_images\crop_2870.png
# C:\Users\user\Desktop\cropped_images\961_069\0225.png -> C:\Users\user\Desktop\selected_images\crop_2871.png
# C:\Users\user\Desktop\cropped_images\961_069\0250.png -> C:\Users\user\Desktop\selected_images\crop_2872.png
# C:\Users\user\Desktop\cropped_images\961_069\0275.png -> C:\Users\user\Desktop\selected_images\crop_2873.png
# C:\Users\user\Desktop\cropped_images\962_929\0375.png -> C:\Users\user\Desktop\selected_images\crop_2874.png
# C:\Users\user\Desktop\cropped_images\962_929\0400.png -> C:\Users\user\Desktop\selected_images\crop_2875.png
# C:\Users\user\Desktop\cropped_images\962_929\0425.png -> C:\Users\user\Desktop\selected_images\crop_2876.png
# C:\Users\user\Desktop\cropped_images\963_879\0550.png -> C:\Users\user\Desktop\selected_images\crop_2877.png
# C:\Users\user\Desktop\cropped_images\963_879\0575.png -> C:\Users\user\Desktop\selected_images\crop_2878.png
# C:\Users\user\Desktop\cropped_images\963_879\0600.png -> C:\Users\user\Desktop\selected_images\crop_2879.png
# C:\Users\user\Desktop\cropped_images\964_174\0375.png -> C:\Users\user\Desktop\selected_images\crop_2880.png
# C:\Users\user\Desktop\cropped_images\964_174\0400.png -> C:\Users\user\Desktop\selected_images\crop_2881.png
# C:\Users\user\Desktop\cropped_images\964_174\0425.png -> C:\Users\user\Desktop\selected_images\crop_2882.png
# C:\Users\user\Desktop\cropped_images\965_948\0250.png -> C:\Users\user\Desktop\selected_images\crop_2883.png
# C:\Users\user\Desktop\cropped_images\965_948\0275.png -> C:\Users\user\Desktop\selected_images\crop_2884.png
# C:\Users\user\Desktop\cropped_images\965_948\0300.png -> C:\Users\user\Desktop\selected_images\crop_2885.png
# C:\Users\user\Desktop\cropped_images\966_988\0275.png -> C:\Users\user\Desktop\selected_images\crop_2886.png
# C:\Users\user\Desktop\cropped_images\966_988\0300.png -> C:\Users\user\Desktop\selected_images\crop_2887.png
# C:\Users\user\Desktop\cropped_images\966_988\0325.png -> C:\Users\user\Desktop\selected_images\crop_2888.png
# C:\Users\user\Desktop\cropped_images\967_984\0325.png -> C:\Users\user\Desktop\selected_images\crop_2889.png
# C:\Users\user\Desktop\cropped_images\967_984\0350.png -> C:\Users\user\Desktop\selected_images\crop_2890.png
# C:\Users\user\Desktop\cropped_images\967_984\0375.png -> C:\Users\user\Desktop\selected_images\crop_2891.png
# C:\Users\user\Desktop\cropped_images\968_884\0200.png -> C:\Users\user\Desktop\selected_images\crop_2892.png
# C:\Users\user\Desktop\cropped_images\968_884\0225.png -> C:\Users\user\Desktop\selected_images\crop_2893.png
# C:\Users\user\Desktop\cropped_images\968_884\0250.png -> C:\Users\user\Desktop\selected_images\crop_2894.png
# C:\Users\user\Desktop\cropped_images\969_897\0275.png -> C:\Users\user\Desktop\selected_images\crop_2895.png
# C:\Users\user\Desktop\cropped_images\969_897\0300.png -> C:\Users\user\Desktop\selected_images\crop_2896.png
# C:\Users\user\Desktop\cropped_images\969_897\0325.png -> C:\Users\user\Desktop\selected_images\crop_2897.png
# C:\Users\user\Desktop\cropped_images\970_973\0400.png -> C:\Users\user\Desktop\selected_images\crop_2898.png
# C:\Users\user\Desktop\cropped_images\970_973\0425.png -> C:\Users\user\Desktop\selected_images\crop_2899.png
# C:\Users\user\Desktop\cropped_images\970_973\0450.png -> C:\Users\user\Desktop\selected_images\crop_2900.png
# C:\Users\user\Desktop\cropped_images\971_564\0275.png -> C:\Users\user\Desktop\selected_images\crop_2901.png
# C:\Users\user\Desktop\cropped_images\971_564\0300.png -> C:\Users\user\Desktop\selected_images\crop_2902.png
# C:\Users\user\Desktop\cropped_images\971_564\0325.png -> C:\Users\user\Desktop\selected_images\crop_2903.png
# C:\Users\user\Desktop\cropped_images\972_718\0225.png -> C:\Users\user\Desktop\selected_images\crop_2904.png
# C:\Users\user\Desktop\cropped_images\972_718\0250.png -> C:\Users\user\Desktop\selected_images\crop_2905.png
# C:\Users\user\Desktop\cropped_images\972_718\0275.png -> C:\Users\user\Desktop\selected_images\crop_2906.png
# C:\Users\user\Desktop\cropped_images\973_970\0450.png -> C:\Users\user\Desktop\selected_images\crop_2907.png
# C:\Users\user\Desktop\cropped_images\973_970\0475.png -> C:\Users\user\Desktop\selected_images\crop_2908.png
# C:\Users\user\Desktop\cropped_images\973_970\0500.png -> C:\Users\user\Desktop\selected_images\crop_2909.png
# C:\Users\user\Desktop\cropped_images\974_953\0225.png -> C:\Users\user\Desktop\selected_images\crop_2910.png
# C:\Users\user\Desktop\cropped_images\974_953\0250.png -> C:\Users\user\Desktop\selected_images\crop_2911.png
# C:\Users\user\Desktop\cropped_images\974_953\0275.png -> C:\Users\user\Desktop\selected_images\crop_2912.png
# C:\Users\user\Desktop\cropped_images\975_978\0225.png -> C:\Users\user\Desktop\selected_images\crop_2913.png
# C:\Users\user\Desktop\cropped_images\975_978\0250.png -> C:\Users\user\Desktop\selected_images\crop_2914.png
# C:\Users\user\Desktop\cropped_images\975_978\0275.png -> C:\Users\user\Desktop\selected_images\crop_2915.png
# C:\Users\user\Desktop\cropped_images\976_954\0250.png -> C:\Users\user\Desktop\selected_images\crop_2916.png
# C:\Users\user\Desktop\cropped_images\976_954\0275.png -> C:\Users\user\Desktop\selected_images\crop_2917.png
# C:\Users\user\Desktop\cropped_images\976_954\0300.png -> C:\Users\user\Desktop\selected_images\crop_2918.png
# C:\Users\user\Desktop\cropped_images\977_075\0575.png -> C:\Users\user\Desktop\selected_images\crop_2919.png
# C:\Users\user\Desktop\cropped_images\977_075\0600.png -> C:\Users\user\Desktop\selected_images\crop_2920.png
# C:\Users\user\Desktop\cropped_images\977_075\0625.png -> C:\Users\user\Desktop\selected_images\crop_2921.png
# C:\Users\user\Desktop\cropped_images\978_975\0675.png -> C:\Users\user\Desktop\selected_images\crop_2922.png
# C:\Users\user\Desktop\cropped_images\978_975\0700.png -> C:\Users\user\Desktop\selected_images\crop_2923.png
# C:\Users\user\Desktop\cropped_images\978_975\0725.png -> C:\Users\user\Desktop\selected_images\crop_2924.png
# C:\Users\user\Desktop\cropped_images\979_875\0250.png -> C:\Users\user\Desktop\selected_images\crop_2925.png
# C:\Users\user\Desktop\cropped_images\979_875\0275.png -> C:\Users\user\Desktop\selected_images\crop_2926.png
# C:\Users\user\Desktop\cropped_images\979_875\0300.png -> C:\Users\user\Desktop\selected_images\crop_2927.png
# C:\Users\user\Desktop\cropped_images\980_992\0300.png -> C:\Users\user\Desktop\selected_images\crop_2928.png
# C:\Users\user\Desktop\cropped_images\980_992\0325.png -> C:\Users\user\Desktop\selected_images\crop_2929.png
# C:\Users\user\Desktop\cropped_images\980_992\0350.png -> C:\Users\user\Desktop\selected_images\crop_2930.png
# C:\Users\user\Desktop\cropped_images\981_985\0275.png -> C:\Users\user\Desktop\selected_images\crop_2931.png
# C:\Users\user\Desktop\cropped_images\981_985\0300.png -> C:\Users\user\Desktop\selected_images\crop_2932.png
# C:\Users\user\Desktop\cropped_images\981_985\0325.png -> C:\Users\user\Desktop\selected_images\crop_2933.png
# C:\Users\user\Desktop\cropped_images\982_004\0750.png -> C:\Users\user\Desktop\selected_images\crop_2934.png
# C:\Users\user\Desktop\cropped_images\982_004\0775.png -> C:\Users\user\Desktop\selected_images\crop_2935.png
# C:\Users\user\Desktop\cropped_images\982_004\0800.png -> C:\Users\user\Desktop\selected_images\crop_2936.png
# C:\Users\user\Desktop\cropped_images\983_113\0325.png -> C:\Users\user\Desktop\selected_images\crop_2937.png
# C:\Users\user\Desktop\cropped_images\983_113\0350.png -> C:\Users\user\Desktop\selected_images\crop_2938.png
# C:\Users\user\Desktop\cropped_images\983_113\0375.png -> C:\Users\user\Desktop\selected_images\crop_2939.png
# C:\Users\user\Desktop\cropped_images\984_967\0250.png -> C:\Users\user\Desktop\selected_images\crop_2940.png
# C:\Users\user\Desktop\cropped_images\984_967\0275.png -> C:\Users\user\Desktop\selected_images\crop_2941.png
# C:\Users\user\Desktop\cropped_images\984_967\0300.png -> C:\Users\user\Desktop\selected_images\crop_2942.png
# C:\Users\user\Desktop\cropped_images\985_981\0250.png -> C:\Users\user\Desktop\selected_images\crop_2943.png
# C:\Users\user\Desktop\cropped_images\985_981\0275.png -> C:\Users\user\Desktop\selected_images\crop_2944.png
# C:\Users\user\Desktop\cropped_images\985_981\0300.png -> C:\Users\user\Desktop\selected_images\crop_2945.png
# C:\Users\user\Desktop\cropped_images\986_994\0750.png -> C:\Users\user\Desktop\selected_images\crop_2946.png
# C:\Users\user\Desktop\cropped_images\986_994\0775.png -> C:\Users\user\Desktop\selected_images\crop_2947.png
# C:\Users\user\Desktop\cropped_images\986_994\0800.png -> C:\Users\user\Desktop\selected_images\crop_2948.png
# C:\Users\user\Desktop\cropped_images\987_938\0475.png -> C:\Users\user\Desktop\selected_images\crop_2949.png
# C:\Users\user\Desktop\cropped_images\987_938\0500.png -> C:\Users\user\Desktop\selected_images\crop_2950.png
# C:\Users\user\Desktop\cropped_images\987_938\0525.png -> C:\Users\user\Desktop\selected_images\crop_2951.png
# C:\Users\user\Desktop\cropped_images\988_966\0375.png -> C:\Users\user\Desktop\selected_images\crop_2952.png
# C:\Users\user\Desktop\cropped_images\988_966\0400.png -> C:\Users\user\Desktop\selected_images\crop_2953.png
# C:\Users\user\Desktop\cropped_images\988_966\0425.png -> C:\Users\user\Desktop\selected_images\crop_2954.png
# C:\Users\user\Desktop\cropped_images\989_993\0875.png -> C:\Users\user\Desktop\selected_images\crop_2955.png
# C:\Users\user\Desktop\cropped_images\989_993\0900.png -> C:\Users\user\Desktop\selected_images\crop_2956.png
# C:\Users\user\Desktop\cropped_images\989_993\0925.png -> C:\Users\user\Desktop\selected_images\crop_2957.png
# C:\Users\user\Desktop\cropped_images\990_008\0200.png -> C:\Users\user\Desktop\selected_images\crop_2958.png
# C:\Users\user\Desktop\cropped_images\990_008\0225.png -> C:\Users\user\Desktop\selected_images\crop_2959.png
# C:\Users\user\Desktop\cropped_images\990_008\0250.png -> C:\Users\user\Desktop\selected_images\crop_2960.png
# C:\Users\user\Desktop\cropped_images\991_064\0325.png -> C:\Users\user\Desktop\selected_images\crop_2961.png
# C:\Users\user\Desktop\cropped_images\991_064\0350.png -> C:\Users\user\Desktop\selected_images\crop_2962.png
# C:\Users\user\Desktop\cropped_images\991_064\0375.png -> C:\Users\user\Desktop\selected_images\crop_2963.png
# C:\Users\user\Desktop\cropped_images\992_980\0600.png -> C:\Users\user\Desktop\selected_images\crop_2964.png
# C:\Users\user\Desktop\cropped_images\992_980\0625.png -> C:\Users\user\Desktop\selected_images\crop_2965.png
# C:\Users\user\Desktop\cropped_images\992_980\0675.png -> C:\Users\user\Desktop\selected_images\crop_2966.png
# C:\Users\user\Desktop\cropped_images\993_989\0325.png -> C:\Users\user\Desktop\selected_images\crop_2967.png
# C:\Users\user\Desktop\cropped_images\993_989\0350.png -> C:\Users\user\Desktop\selected_images\crop_2968.png
# C:\Users\user\Desktop\cropped_images\993_989\0375.png -> C:\Users\user\Desktop\selected_images\crop_2969.png
# C:\Users\user\Desktop\cropped_images\994_986\0225.png -> C:\Users\user\Desktop\selected_images\crop_2970.png
# C:\Users\user\Desktop\cropped_images\994_986\0250.png -> C:\Users\user\Desktop\selected_images\crop_2971.png
# C:\Users\user\Desktop\cropped_images\994_986\0275.png -> C:\Users\user\Desktop\selected_images\crop_2972.png
# C:\Users\user\Desktop\cropped_images\995_233\0450.png -> C:\Users\user\Desktop\selected_images\crop_2973.png
# C:\Users\user\Desktop\cropped_images\995_233\0475.png -> C:\Users\user\Desktop\selected_images\crop_2974.png
# C:\Users\user\Desktop\cropped_images\995_233\0500.png -> C:\Users\user\Desktop\selected_images\crop_2975.png
# C:\Users\user\Desktop\cropped_images\996_056\0225.png -> C:\Users\user\Desktop\selected_images\crop_2976.png
# C:\Users\user\Desktop\cropped_images\996_056\0250.png -> C:\Users\user\Desktop\selected_images\crop_2977.png
# C:\Users\user\Desktop\cropped_images\996_056\0275.png -> C:\Users\user\Desktop\selected_images\crop_2978.png
# C:\Users\user\Desktop\cropped_images\997_040\0350.png -> C:\Users\user\Desktop\selected_images\crop_2979.png
# C:\Users\user\Desktop\cropped_images\997_040\0375.png -> C:\Users\user\Desktop\selected_images\crop_2980.png
# C:\Users\user\Desktop\cropped_images\997_040\0400.png -> C:\Users\user\Desktop\selected_images\crop_2981.png
# C:\Users\user\Desktop\cropped_images\998_561\0250.png -> C:\Users\user\Desktop\selected_images\crop_2982.png
# C:\Users\user\Desktop\cropped_images\998_561\0275.png -> C:\Users\user\Desktop\selected_images\crop_2983.png
# C:\Users\user\Desktop\cropped_images\998_561\0300.png -> C:\Users\user\Desktop\selected_images\crop_2984.png
# C:\Users\user\Desktop\cropped_images\999_960\0250.png -> C:\Users\user\Desktop\selected_images\crop_2985.png
# C:\Users\user\Desktop\cropped_images\999_960\0275.png -> C:\Users\user\Desktop\selected_images\crop_2986.png
# C:\Users\user\Desktop\cropped_images\999_960\0300.png -> C:\Users\user\Desktop\selected_images\crop_2987.png
# 이미지 복사가 완료되었습니다.
